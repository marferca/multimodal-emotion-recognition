# %% [markdown]
# # Late Fusion: Audio Modeling

# %% [markdown]
# ## Setup

# %%
import os
from glob import glob
from pathlib import Path
from tqdm import tqdm

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import sklearn as sk
import pickle
import copy

from sklearn.model_selection import LeaveOneGroupOut
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.utils.class_weight import compute_class_weight

# %% [markdown]
# ### Paths

# %%
input_path = '../../../2.data_preparation/out/audio/'
output_path = '../out/audio/'
# Global configuration path
glob_conf_path = '../../../config/global_config_paper.py'

# %% [markdown]
# ### Load global variables

# %%
exec(open(glob_conf_path).read())

# %% [markdown]
# ### Load and shuffle data

# %%
egemaps_df = pd.read_csv(os.path.join(input_path, 'egemaps', 'audio_data_egemaps_train.csv'))
gemaps_df = pd.read_csv(os.path.join(input_path, 'gemaps', 'audio_data_gemaps_train.csv'))

# %%
egemaps_df
# Out:
#       F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                              0.579782
# 1                              0.393945
# 2                              0.487920
# 3                              0.415525
# 4                              0.578382
# ...                                 ...
# 1254                           0.455030
# 1255                           0.220083
# 1256                           0.270762
# 1257                           0.450948
# 1258                           0.349244
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                   0.276111
# 1                                   0.343674
# 2                                   0.288303
# 3                                   0.320765
# 4                                   0.277224
# ...                                      ...
# 1254                                0.051548
# 1255                                0.513768
# 1256                                0.520014
# 1257                                0.089263
# 1258                                0.336031
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                       0.533631
# 1                                       0.384970
# 2                                       0.466380
# 3                                       0.357067
# 4                                       0.455800
# ...                                          ...
# 1254                                    0.459465
# 1255                                    0.031770
# 1256                                    0.024084
# 1257                                    0.419079
# 1258                                    0.397092
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                       0.596311
# 1                                       0.423466
# 2                                       0.452395
# 3                                       0.355146
# 4                                       0.559710
# ...                                          ...
# 1254                                    0.432665
# 1255                                    0.317742
# 1256                                    0.363869
# 1257                                    0.440764
# 1258                                    0.381677
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                       0.632179
# 1                                       0.446001
# 2                                       0.584362
# 3                                       0.490685
# 4                                       0.627945
# ...                                          ...
# 1254                                    0.428898
# 1255                                    0.347561
# 1256                                    0.372689
# 1257                                    0.442042
# 1258                                    0.380470
#
#       F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                     0.209500
# 1                                     0.147274
# 2                                     0.226165
# 3                                     0.233617
# 4                                     0.291699
# ...                                        ...
# 1254                                  0.042556
# 1255                                  0.422764
# 1256                                  0.462329
# 1257                                  0.104093
# 1258                                  0.052991
#
#       F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# 0                                        0.178389
# 1                                        0.282919
# 2                                        0.321936
# 3                                        0.187911
# 4                                        0.210346
# ...                                           ...
# 1254                                     0.136981
# 1255                                     0.358086
# 1256                                     0.259245
# 1257                                     0.162826
# 1258                                     0.227318
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  \
# 0                                          0.032262
# 1                                          0.175538
# 2                                          0.164298
# 3                                          0.038932
# 4                                          0.112102
# ...                                             ...
# 1254                                       0.009610
# 1255                                       0.306875
# 1256                                       0.118235
# 1257                                       0.065396
# 1258                                       0.087805
#
#       F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope  \
# 0                                         0.261604
# 1                                         0.267522
# 2                                         0.311106
# 3                                         0.222829
# 4                                         0.258617
# ...                                            ...
# 1254                                      0.209519
# 1255                                      0.228330
# 1256                                      0.245574
# 1257                                      0.205408
# 1258                                      0.235091
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope  ...  \
# 0                                           0.070276  ...
# 1                                           0.068505  ...
# 2                                           0.203101  ...
# 3                                           0.040867  ...
# 4                                           0.044221  ...
# ...                                              ...  ...
# 1254                                        0.008897  ...
# 1255                                        0.014988  ...
# 1256                                        0.060586  ...
# 1257                                        0.005887  ...
# 1258                                        0.048350  ...
#
#       VoicedSegmentsPerSec  MeanVoicedSegmentLengthSec  \
# 0                 0.330578                    0.037114
# 1                 0.264558                    0.055237
# 2                 0.344937                    0.038350
# 3                 0.337101                    0.039662
# 4                 0.161629                    0.090247
# ...                    ...                         ...
# 1254              0.192274                    0.065019
# 1255              0.396111                    0.023316
# 1256              0.376332                    0.022740
# 1257              0.155720                    0.063989
# 1258              0.324766                    0.029237
#
#       StddevVoicedSegmentLengthSec  MeanUnvoicedSegmentLength  \
# 0                         0.117179                   0.047826
# 1                         0.089090                   0.057971
# 2                         0.090084                   0.050725
# 3                         0.074729                   0.045894
# 4                         0.320940                   0.045894
# ...                            ...                        ...
# 1254                      0.064878                   0.086957
# 1255                      0.090696                   0.077122
# 1256                      0.107705                   0.091938
# 1257                      0.077539                   0.134058
# 1258                      0.098803                   0.072464
#
#       StddevUnvoicedSegmentLength  equivalentSoundLevel_dBp  actor_id  \
# 0                        0.088380                  0.731259         1
# 1                        0.000000                  0.725443         1
# 2                        0.049834                  0.742759         1
# 3                        0.040150                  0.789177         1
# 4                        0.058668                  0.764986         1
# ...                           ...                       ...       ...
# 1254                     0.127309                  0.693686        10
# 1255                     0.096082                  0.760948        10
# 1256                     0.147996                  0.786001        10
# 1257                     0.268334                  0.721901        10
# 1258                     0.082329                  0.726299        10
#
#       file_id  target  group
# 0           0       1      4
# 1           1       1      4
# 2           2       1      4
# 3           3       1      4
# 4           4       1      4
# ...       ...     ...    ...
# 1254     1255      17      5
# 1255     1256      17      5
# 1256     1257      17      5
# 1257     1258      17      5
# 1258     1259      17      5
#
# [1259 rows x 92 columns]

# %%
from sklearn.utils import shuffle

egemaps_shuffled_df = shuffle(egemaps_df, random_state=seed).reset_index(drop=True)
gemaps_shuffled_df = shuffle(gemaps_df, random_state=seed).reset_index(drop=True)

# %%
egemaps_shuffled_df
# Out:
#       F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                              0.240379
# 1                              0.428243
# 2                              0.499724
# 3                              0.294653
# 4                              0.154184
# ...                                 ...
# 1254                           0.800665
# 1255                           0.339490
# 1256                           0.628904
# 1257                           0.663620
# 1258                           0.433342
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                   0.614553
# 1                                   0.121044
# 2                                   0.243378
# 3                                   0.605192
# 4                                   0.620439
# ...                                      ...
# 1254                                0.175227
# 1255                                0.457571
# 1256                                0.354822
# 1257                                0.149773
# 1258                                0.312574
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                       0.089265
# 1                                       0.397641
# 2                                       0.437738
# 3                                       0.026334
# 4                                       0.076768
# ...                                          ...
# 1254                                    0.745947
# 1255                                    0.146215
# 1256                                    0.665858
# 1257                                    0.618283
# 1258                                    0.372422
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                       0.219347
# 1                                       0.397569
# 2                                       0.420981
# 3                                       0.314250
# 4                                       0.134368
# ...                                          ...
# 1254                                    0.790104
# 1255                                    0.395539
# 1256                                    0.633961
# 1257                                    0.661143
# 1258                                    0.414017
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                       0.284260
# 1                                       0.437531
# 2                                       0.586214
# 3                                       0.475608
# 4                                       0.172950
# ...                                          ...
# 1254                                    0.808547
# 1255                                    0.453824
# 1256                                    0.696183
# 1257                                    0.654561
# 1258                                    0.500070
#
#       F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                     0.280270
# 1                                     0.122617
# 2                                     0.260613
# 3                                     0.586494
# 4                                     0.157283
# ...                                        ...
# 1254                                  0.188162
# 1255                                  0.425043
# 1256                                  0.139788
# 1257                                  0.141982
# 1258                                  0.227925
#
#       F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# 0                                        0.303624
# 1                                        0.148100
# 2                                        0.142826
# 3                                        0.137131
# 4                                        0.179695
# ...                                           ...
# 1254                                     0.173931
# 1255                                     0.180069
# 1256                                     0.381234
# 1257                                     0.142250
# 1258                                     0.150683
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  \
# 0                                          0.200022
# 1                                          0.015786
# 2                                          0.018867
# 3                                          0.002755
# 4                                          0.035599
# ...                                             ...
# 1254                                       0.011665
# 1255                                       0.018150
# 1256                                       0.154791
# 1257                                       0.015549
# 1258                                       0.021006
#
#       F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope  \
# 0                                         0.262954
# 1                                         0.218510
# 2                                         0.205943
# 3                                         0.226926
# 4                                         0.277163
# ...                                            ...
# 1254                                      0.205735
# 1255                                      0.230690
# 1256                                      0.274983
# 1257                                      0.208364
# 1258                                      0.256828
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope  ...  \
# 0                                           0.033284  ...
# 1                                           0.011256  ...
# 2                                           0.003317  ...
# 3                                           0.000000  ...
# 4                                           0.124323  ...
# ...                                              ...  ...
# 1254                                        0.023853  ...
# 1255                                        0.016112  ...
# 1256                                        0.100322  ...
# 1257                                        0.004063  ...
# 1258                                        0.061566  ...
#
#       VoicedSegmentsPerSec  MeanVoicedSegmentLengthSec  \
# 0                 0.235860                    0.045146
# 1                 0.311049                    0.026147
# 2                 0.134254                    0.114960
# 3                 0.378653                    0.019025
# 4                 0.240382                    0.047964
# ...                    ...                         ...
# 1254              0.100549                    0.115733
# 1255              0.275777                    0.033870
# 1256              0.386604                    0.024603
# 1257              0.105917                    0.096812
# 1258              0.303333                    0.034951
#
#       StddevVoicedSegmentLengthSec  MeanUnvoicedSegmentLength  \
# 0                         0.114542                   0.072464
# 1                         0.037864                   0.115942
# 2                         0.138889                   0.043478
# 3                         0.143761                   0.100644
# 4                         0.202761                   0.067391
# ...                            ...                        ...
# 1254                      0.295122                   0.115942
# 1255                      0.113277                   0.076812
# 1256                      0.093439                   0.082609
# 1257                      0.233341                   0.230072
# 1258                      0.115740                   0.072464
#
#       StddevUnvoicedSegmentLength  equivalentSoundLevel_dBp  actor_id  \
# 0                        0.140819                  0.082002         3
# 1                        0.204594                  0.731306         9
# 2                        0.000000                  0.478746         8
# 3                        0.155143                  0.633834         9
# 4                        0.060728                  0.159401         3
# ...                           ...                       ...       ...
# 1254                     0.090744                  0.838798         2
# 1255                     0.033838                  0.792443         9
# 1256                     0.087039                  0.584423         6
# 1257                     0.270494                  0.694067         5
# 1258                     0.053134                  0.734848         9
#
#       file_id  target  group
# 0         315       9      3
# 1        1117      15      4
# 2         987      14      5
# 3        1067       9      4
# 4         323       9      3
# ...       ...     ...    ...
# 1254      141       3      1
# 1255     1049       6      4
# 1256      753      17      2
# 1257      543       6      3
# 1258     1044       6      4
#
# [1259 rows x 92 columns]

# %% [markdown]
# ## Other functions

# %%
from sklearn.metrics import confusion_matrix
    
def plot_save_conf_matrix(X, y, cv, clf, title, file_name, report=False):
    
    # Initialize some variables to store results
    conf_mat_avg = np.zeros([18,18])
    n_groups = 0
    for train_idx, val_idx in cv:
        n_groups += 1
        X_train, X_val, y_train, y_val = X.iloc[train_idx], X.iloc[val_idx], y.iloc[train_idx], y.iloc[val_idx]
        
        clf.fit(X_train,y_train)
        
        # Compute results (validation dataset)    
        y_pred = clf.predict(X_val)                       # Predict class
        conf_mat_tmp = confusion_matrix(y_val,            # Compute confusion matrix for this batch
                                        y_pred,
                                        normalize='true'
                                       )
        conf_mat_avg += conf_mat_tmp
    
    conf_mat_avg /= n_groups
    
    
    df_cm = pd.DataFrame(conf_mat_avg, list(emotion_id_to_emotion_num.keys()), list(emotion_id_to_emotion_num.keys()))
    
    plt.figure(figsize=(15,15))
    ax = sns.heatmap(df_cm, annot=True, fmt='.2f', vmin=0, vmax=1, cmap=conf_cmap)
    plt.yticks(va='center')
    plt.xlabel('Predicted Label')
    plt.ylabel('Actual Label')
    if report == True:
        plt.savefig(os.path.join(output_path,'confusion_matrix','report_'+file_name), bbox_inches = 'tight') 
    plt.title(title)
    plt.savefig(os.path.join(output_path,'confusion_matrix',file_name), bbox_inches = 'tight')

# %% [markdown]
# ## Elastic Net SGD Classifier

# %% [markdown]
# ### eGeMAPS

# %%
from sklearn.linear_model import SGDClassifier

# Obtain X, y, and groups from the training dataset
X = egemaps_shuffled_df.drop(columns=['target','file_id','actor_id', 'group'])
y = egemaps_shuffled_df.target
groups = egemaps_shuffled_df.group
n_groups = len(groups.unique())


# Define parameters to evaluate
alpha_values            = [0.0001, 0.00025, 0.0005, 0.00075, 0.001, 0.005, 0.0025, 0.0075, 0.01, 0.05, 0.1, 1]
n_iter_no_change_values = [20, 50, 100, 150]
l1_ratio_values         = [0.049, 0.10, 0.15, 0.20, 0.25, 0.30, 0.35, 0.40, 0.45, 0.50,
                           0.55, 0.60, 0.65, 0.70, 0.75, 0.80, 0.85, 0.89, 0.95, 0.99]
parameters              = {'penalty': ['elasticnet'],
                           'class_weight': ['balanced'],
                           'loss': ['log'],
                           'random_state': [seed],
                           'alpha': alpha_values,
                           'l1_ratio': l1_ratio_values,
                           'n_iter_no_change': n_iter_no_change_values,
                           'max_iter': [2500]
                          }

elasticnet = SGDClassifier()
logo = LeaveOneGroupOut()

clf = GridSearchCV(estimator  = elasticnet, 
                   param_grid = parameters,
                   scoring    = 'roc_auc_ovo_weighted',
                   cv         = logo.split(X=X,groups=groups),
                   verbose    = 1,
                   n_jobs     = -1,
                  )
clf.fit(X,y)
print(clf.best_estimator_)

# Store results in a DataFrame and then save them as csv
results_df = pd.DataFrame(clf.cv_results_)
results_df.to_csv(os.path.join(output_path,'results','res_elastic_net_'+str(n_groups)+'_logocv_egemaps_audio.csv'), index=None, header=True)

# Save best parameters to disk
file_path = os.path.join(output_path,'best_params','best_params_elastic_net_egemaps_audio.sav')
pickle.dump(clf.best_params_, open(file_path, 'wb'))

# Save the best model to disk
file_path = os.path.join(output_path,'models','mod_elastic_net_egemaps_audio.sav')
pickle.dump(clf.best_estimator_, open(file_path, 'wb'))
# Out:
# Fitting 5 folds for each of 960 candidates, totalling 4800 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   55.4s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed: 18.9min
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed: 24.9min
# [Parallel(n_jobs=-1)]: Done 2442 tasks      | elapsed: 30.6min
# [Parallel(n_jobs=-1)]: Done 3192 tasks      | elapsed: 36.8min
# [Parallel(n_jobs=-1)]: Done 4042 tasks      | elapsed: 42.9min
# [Parallel(n_jobs=-1)]: Done 4800 out of 4800 | elapsed: 48.4min finished
# SGDClassifier(alpha=0.00075, average=False, class_weight='balanced',
#               early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#               l1_ratio=0.3, learning_rate='optimal', loss='log', max_iter=2500,
#               n_iter_no_change=100, n_jobs=None, penalty='elasticnet',
#               power_t=0.5, random_state=27, shuffle=True, tol=0.001,
#               validation_fraction=0.1, verbose=0, warm_start=False)

# %%
results_df.sort_values(by="rank_test_score").head(3)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 262       3.114908      0.043891         0.239309        0.005154     0.00075
# 268       0.896764      0.022112         0.245781        0.016881     0.00075
# 263       4.142454      0.091232         0.242406        0.012333     0.00075
#
#     param_class_weight param_l1_ratio param_loss param_max_iter  \
# 262           balanced            0.3        log           2500
# 268           balanced            0.4        log           2500
# 263           balanced            0.3        log           2500
#
#     param_n_iter_no_change  ... param_random_state  \
# 262                    100  ...                 27
# 268                     20  ...                 27
# 263                    150  ...                 27
#
#                                                 params split0_test_score  \
# 262  {'alpha': 0.00075, 'class_weight': 'balanced',...          0.836770
# 268  {'alpha': 0.00075, 'class_weight': 'balanced',...          0.838326
# 263  {'alpha': 0.00075, 'class_weight': 'balanced',...          0.836809
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 262           0.793586           0.839243           0.799448
# 268           0.795038           0.837851           0.797645
# 263           0.794351           0.838399           0.798708
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 262           0.829067         0.819623        0.019252                1
# 268           0.829209         0.819614        0.019295                2
# 263           0.829715         0.819596        0.019109                3
#
# [3 rows x 21 columns]

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import cross_validate

# Obtain X, y, and groups from the training dataset
X = egemaps_shuffled_df.drop(columns=['target','file_id','actor_id', 'group'])
y = egemaps_shuffled_df.target
groups = egemaps_shuffled_df.group

logo = LeaveOneGroupOut()


# Load best parameters
file_path = os.path.join(output_path,'best_params','best_params_elastic_net_egemaps_audio.sav')
best_params = pickle.load(open(file_path, 'rb'))
                   
clf = SGDClassifier(**best_params)

scores = cross_validate(X=X, y=y,
                        estimator           = clf,
                        scoring             = ['roc_auc_ovo_weighted'],
                        cv                  = logo.split(X=X,groups=groups),
                        verbose             = 1,
                        n_jobs              = -1
                       )

print('AUC_avg (validation):', np.mean(scores['test_roc_auc_ovo_weighted']))
print('AUC_std (validation):', np.std(scores['test_roc_auc_ovo_weighted']))

# Confusion matrix
plot_save_conf_matrix(X         = X,
                      y         = y,
                      cv        = logo.split(X=X,groups=groups),
                      clf       = clf,
                      title     = 'Elastic Net Normalized Confusion Matrix (Audio eGeMAPS Validation Set)',
                      file_name = 'conf_mat_elastic_net_egemaps_audio.svg'
                     )
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    8.7s finished
# AUC_avg (validation): 0.8196226025759105
# AUC_std (validation): 0.019251567913203416

# %% [markdown]
# ### GeMAPS

# %%
from sklearn.linear_model import SGDClassifier

# Obtain X, y, and groups from the training dataset
X = gemaps_shuffled_df.drop(columns=['target','file_id','actor_id', 'group'])
y = gemaps_shuffled_df.target
groups = gemaps_shuffled_df.group
n_groups = len(groups.unique())


# Define parameters to evaluate
alpha_values            = [0.0001, 0.00025, 0.0005, 0.00075, 0.001, 0.005, 0.0025, 0.0075, 0.01, 0.05, 0.1, 1]
n_iter_no_change_values = [20, 50, 100, 150]
l1_ratio_values         = [0.049, 0.10, 0.15, 0.20, 0.25, 0.30, 0.35, 0.40, 0.45, 0.50,
                           0.55, 0.60, 0.65, 0.70, 0.75, 0.80, 0.85, 0.89, 0.95, 0.99]
parameters              = {'penalty': ['elasticnet'],
                           'class_weight': ['balanced'],
                           'loss': ['log'],
                           'random_state': [seed],
                           'alpha': alpha_values,
                           'l1_ratio': l1_ratio_values,
                           'n_iter_no_change': n_iter_no_change_values,
                           'max_iter': [2500]
                          }

elasticnet = SGDClassifier()
logo = LeaveOneGroupOut()

clf = GridSearchCV(estimator  = elasticnet, 
                   param_grid = parameters,
                   scoring    = 'roc_auc_ovo_weighted',
                   cv         = logo.split(X=X,groups=groups),
                   verbose    = 1,
                   n_jobs     = -1,
                  )
clf.fit(X,y)
print(clf.best_estimator_)

# Store results in a DataFrame and then save them as csv
results_df = pd.DataFrame(clf.cv_results_)
results_df.to_csv(os.path.join(output_path,'results','res_elastic_net_'+str(n_groups)+'_logocv_gemaps_audio.csv'), index=None, header=True)

# Save best parameters to disk
file_path = os.path.join(output_path,'best_params','best_params_elastic_net_gemaps_audio.sav')
pickle.dump(clf.best_params_, open(file_path, 'wb'))

# Save the best model to disk
file_path = os.path.join(output_path,'models','mod_elastic_net_gemaps_audio.sav')
pickle.dump(clf.best_estimator_, open(file_path, 'wb'))
# Out:
# Fitting 5 folds for each of 960 candidates, totalling 4800 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   32.5s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed: 17.2min
# [Parallel(n_jobs=-1)]: Done 2442 tasks      | elapsed: 21.4min
# [Parallel(n_jobs=-1)]: Done 3192 tasks      | elapsed: 26.0min
# [Parallel(n_jobs=-1)]: Done 4042 tasks      | elapsed: 30.8min
# [Parallel(n_jobs=-1)]: Done 4800 out of 4800 | elapsed: 35.0min finished
# SGDClassifier(alpha=0.0005, average=False, class_weight='balanced',
#               early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#               l1_ratio=0.35, learning_rate='optimal', loss='log', max_iter=2500,
#               n_iter_no_change=100, n_jobs=None, penalty='elasticnet',
#               power_t=0.5, random_state=27, shuffle=True, tol=0.001,
#               validation_fraction=0.1, verbose=0, warm_start=False)

# %%
results_df.sort_values(by="rank_test_score").head(3)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 186       2.242148      0.074045         0.246765        0.003192      0.0005
# 213       1.275865      0.088258         0.260214        0.017487      0.0005
# 194       2.162577      0.087009         0.242535        0.016882      0.0005
#
#     param_class_weight param_l1_ratio param_loss param_max_iter  \
# 186           balanced           0.35        log           2500
# 213           balanced            0.7        log           2500
# 194           balanced           0.45        log           2500
#
#     param_n_iter_no_change  ... param_random_state  \
# 186                    100  ...                 27
# 213                     50  ...                 27
# 194                    100  ...                 27
#
#                                                 params split0_test_score  \
# 186  {'alpha': 0.0005, 'class_weight': 'balanced', ...          0.826473
# 213  {'alpha': 0.0005, 'class_weight': 'balanced', ...          0.829209
# 194  {'alpha': 0.0005, 'class_weight': 'balanced', ...          0.825786
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 186           0.779152           0.825895           0.783432
# 213           0.780358           0.824479           0.780320
# 194           0.779243           0.825691           0.782874
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 186           0.827887         0.808568        0.022321                1
# 213           0.827666         0.808407        0.022968                2
# 194           0.827692         0.808257        0.022249                3
#
# [3 rows x 21 columns]

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import cross_validate

# Obtain X, y, and groups from the training dataset
X = gemaps_shuffled_df.drop(columns=['target','file_id','actor_id', 'group'])
y = gemaps_shuffled_df.target
groups = gemaps_shuffled_df.group

logo = LeaveOneGroupOut()


# Load best parameters
file_path = os.path.join(output_path,'best_params','best_params_elastic_net_gemaps_audio.sav')
best_params = pickle.load(open(file_path, 'rb'))
                   
clf = SGDClassifier(**best_params)

scores = cross_validate(X=X, y=y,
                        estimator           = clf,
                        scoring             = ['roc_auc_ovo_weighted'],
                        cv                  = logo.split(X=X,groups=groups),
                        verbose             = 1,
                        n_jobs              = -1
                       )

print('AUC_avg (validation):', np.mean(scores['test_roc_auc_ovo_weighted']))
print('AUC_std (validation):', np.std(scores['test_roc_auc_ovo_weighted']))

# Confusion matrix
plot_save_conf_matrix(X         = X,
                      y         = y,
                      cv        = logo.split(X=X,groups=groups),
                      clf       = clf,
                      title     = 'Elastic Net Normalized Confusion Matrix (Audio GeMAPS Validation Set)',
                      file_name = 'conf_mat_elastic_net_gemaps_audio.svg'
                     )
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    7.3s finished
# AUC_avg (validation): 0.8085677982187678
# AUC_std (validation): 0.022320966352015758

# %% [markdown]
# ## kNN Classifier

# %% [markdown]
# ### eGeMAPS

# %%
from sklearn.neighbors import KNeighborsClassifier

# Obtain X, y, and groups from the training dataset
X = egemaps_shuffled_df.drop(columns=['target','file_id','actor_id', 'group'])
y = egemaps_shuffled_df.target
groups = egemaps_shuffled_df.group
n_groups = len(groups.unique())


# Define parameters to evaluate
n_neigh_values   = np.arange(50, 405, 5).tolist()
leaf_size_values = np.arange(30, 310, 5).tolist()
weights_values   = ['uniform', 'distance']
parameters      = {'n_neighbors': n_neigh_values,
                   'leaf_size': leaf_size_values,
                   'weights': weights_values,
                   'n_jobs': [-1]
                  }

knn = KNeighborsClassifier()
logo = LeaveOneGroupOut()

clf = GridSearchCV(estimator  = knn, 
                   param_grid = parameters,
                   scoring    = 'roc_auc_ovo_weighted',
                   cv         = logo.split(X=X,groups=groups),
                   verbose    = 1,
                   n_jobs     = -1,
                  )
clf.fit(X,y)
print(clf.best_estimator_)

# Store results in a DataFrame and then save them as csv
results_df = pd.DataFrame(clf.cv_results_)
results_df.to_csv(os.path.join(output_path,'results','res_knn_'+str(n_groups)+'_logocv_egemaps_audio.csv'), index=None, header=True)

# Save best parameters to disk
file_path = os.path.join(output_path,'best_params','best_params_knn_egemaps_audio.sav')
pickle.dump(clf.best_params_, open(file_path, 'wb'))

# Save the best model to disk
file_path = os.path.join(output_path,'models','mod_knn_egemaps_audio.sav')
pickle.dump(clf.best_estimator_, open(file_path, 'wb'))
# Out:
# Fitting 5 folds for each of 7952 candidates, totalling 39760 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   33.4s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 2442 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 3192 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 4042 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 4992 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=-1)]: Done 6042 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 7192 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done 8442 tasks      | elapsed: 14.2min
# [Parallel(n_jobs=-1)]: Done 9792 tasks      | elapsed: 16.4min
# [Parallel(n_jobs=-1)]: Done 11242 tasks      | elapsed: 18.7min
# [Parallel(n_jobs=-1)]: Done 12792 tasks      | elapsed: 21.2min
# [Parallel(n_jobs=-1)]: Done 14442 tasks      | elapsed: 23.9min
# [Parallel(n_jobs=-1)]: Done 16192 tasks      | elapsed: 26.7min
# [Parallel(n_jobs=-1)]: Done 18042 tasks      | elapsed: 29.6min
# [Parallel(n_jobs=-1)]: Done 19992 tasks      | elapsed: 32.7min
# [Parallel(n_jobs=-1)]: Done 22042 tasks      | elapsed: 36.0min
# [Parallel(n_jobs=-1)]: Done 24192 tasks      | elapsed: 39.4min
# [Parallel(n_jobs=-1)]: Done 26442 tasks      | elapsed: 43.1min
# [Parallel(n_jobs=-1)]: Done 28792 tasks      | elapsed: 46.8min
# [Parallel(n_jobs=-1)]: Done 31242 tasks      | elapsed: 50.7min
# [Parallel(n_jobs=-1)]: Done 33792 tasks      | elapsed: 54.8min
# [Parallel(n_jobs=-1)]: Done 36442 tasks      | elapsed: 59.0min
# [Parallel(n_jobs=-1)]: Done 39192 tasks      | elapsed: 63.4min
# [Parallel(n_jobs=-1)]: Done 39760 out of 39760 | elapsed: 64.3min finished
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=175, p=2,
#                      weights='distance')

# %%
results_df.sort_values(by="rank_test_score").head(3)
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 3459       0.008291      0.004555         0.341119        0.019663
# 4595       0.005934      0.001202         0.349007        0.015180
# 3885       0.007091      0.004382         0.354831        0.017227
#
#      param_leaf_size param_n_jobs param_n_neighbors param_weights  \
# 3459             150           -1               175      distance
# 4595             190           -1               175      distance
# 3885             165           -1               175      distance
#
#                                                  params  split0_test_score  \
# 3459  {'leaf_size': 150, 'n_jobs': -1, 'n_neighbors'...           0.795752
# 4595  {'leaf_size': 190, 'n_jobs': -1, 'n_neighbors'...           0.795752
# 3885  {'leaf_size': 165, 'n_jobs': -1, 'n_neighbors'...           0.795752
#
#       split1_test_score  split2_test_score  split3_test_score  \
# 3459           0.750849           0.802222           0.769024
# 4595           0.750849           0.802222           0.769024
# 3885           0.750849           0.802222           0.769024
#
#       split4_test_score  mean_test_score  std_test_score  rank_test_score
# 3459           0.770204          0.77761        0.018866                1
# 4595           0.770204          0.77761        0.018866                1
# 3885           0.770204          0.77761        0.018866                1

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_validate

# Obtain X, y, and groups from the training dataset
X = egemaps_shuffled_df.drop(columns=['target','file_id','actor_id', 'group'])
y = egemaps_shuffled_df.target
groups = egemaps_shuffled_df.group

logo = LeaveOneGroupOut()


# Load best parameters
file_path = os.path.join(output_path,'best_params','best_params_knn_egemaps_audio.sav')
best_params = pickle.load(open(file_path, 'rb'))
                   
clf = KNeighborsClassifier(**best_params)

scores = cross_validate(X=X, y=y,
                        estimator           = clf,
                        scoring             = ['roc_auc_ovo_weighted'],
                        cv                  = logo.split(X=X,groups=groups),
                        verbose             = 1,
                        n_jobs              = -1
                       )

print('AUC_avg (validation):', np.mean(scores['test_roc_auc_ovo_weighted']))
print('AUC_std (validation):', np.std(scores['test_roc_auc_ovo_weighted']))

# Confusion matrix
plot_save_conf_matrix(X         = X,
                      y         = y,
                      cv        = logo.split(X=X,groups=groups),
                      clf       = clf,
                      title     = 'kNN Normalized Confusion Matrix (Audio eGeMAPS Validation Set)',
                      file_name = 'conf_mat_knn_egemaps_audio.svg'
                     )
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.7s finished
# AUC_avg (validation): 0.7776102837996557
# AUC_std (validation): 0.01886553653000847

# %% [markdown]
# ### GeMAPS

# %%
from sklearn.neighbors import KNeighborsClassifier

# Obtain X, y, and groups from the training dataset
X = gemaps_shuffled_df.drop(columns=['target','file_id','actor_id', 'group'])
y = gemaps_shuffled_df.target
groups = gemaps_shuffled_df.group
n_groups = len(groups.unique())


# Define parameters to evaluate
n_neigh_values   = np.arange(50, 405, 5).tolist()
leaf_size_values = np.arange(30, 310, 5).tolist()
weights_values   = ['uniform', 'distance']
parameters      = {'n_neighbors': n_neigh_values,
                   'leaf_size': leaf_size_values,
                   'weights': weights_values,
                   'n_jobs': [-1]
                  }

knn = KNeighborsClassifier()
logo = LeaveOneGroupOut()

clf = GridSearchCV(estimator  = knn, 
                   param_grid = parameters,
                   scoring    = 'roc_auc_ovo_weighted',
                   cv         = logo.split(X=X,groups=groups),
                   verbose    = 1,
                   n_jobs     = -1,
                  )
clf.fit(X,y)
print(clf.best_estimator_)

# Store results in a DataFrame and then save them as csv
results_df = pd.DataFrame(clf.cv_results_)
results_df.to_csv(os.path.join(output_path,'results','res_knn_'+str(n_groups)+'_logocv_gemaps_audio.csv'), index=None, header=True)

# Save best parameters to disk
file_path = os.path.join(output_path,'best_params','best_params_knn_gemaps_audio.sav')
pickle.dump(clf.best_params_, open(file_path, 'wb'))

# Save the best model to disk
file_path = os.path.join(output_path,'models','mod_knn_gemaps_audio.sav')
pickle.dump(clf.best_estimator_, open(file_path, 'wb'))
# Out:
# Fitting 5 folds for each of 7952 candidates, totalling 39760 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   18.7s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:   42.9s
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 2442 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 3192 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 4042 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 4992 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done 6042 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 7192 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done 8442 tasks      | elapsed: 13.4min
# [Parallel(n_jobs=-1)]: Done 9792 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=-1)]: Done 11242 tasks      | elapsed: 17.8min
# [Parallel(n_jobs=-1)]: Done 12792 tasks      | elapsed: 20.2min
# [Parallel(n_jobs=-1)]: Done 14442 tasks      | elapsed: 22.8min
# [Parallel(n_jobs=-1)]: Done 16192 tasks      | elapsed: 25.5min
# [Parallel(n_jobs=-1)]: Done 18042 tasks      | elapsed: 28.4min
# [Parallel(n_jobs=-1)]: Done 19992 tasks      | elapsed: 31.4min
# [Parallel(n_jobs=-1)]: Done 22042 tasks      | elapsed: 34.6min
# [Parallel(n_jobs=-1)]: Done 24192 tasks      | elapsed: 38.0min
# [Parallel(n_jobs=-1)]: Done 26442 tasks      | elapsed: 41.5min
# [Parallel(n_jobs=-1)]: Done 28792 tasks      | elapsed: 45.1min
# [Parallel(n_jobs=-1)]: Done 31242 tasks      | elapsed: 48.9min
# [Parallel(n_jobs=-1)]: Done 33792 tasks      | elapsed: 52.9min
# [Parallel(n_jobs=-1)]: Done 36442 tasks      | elapsed: 57.0min
# [Parallel(n_jobs=-1)]: Done 39192 tasks      | elapsed: 61.2min
# [Parallel(n_jobs=-1)]: Done 39760 out of 39760 | elapsed: 62.1min finished
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=210, p=2,
#                      weights='distance')

# %%
results_df.sort_values(by="rank_test_score").head(3)
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 6171       0.004449      0.000845         0.360201        0.007704
# 6455       0.004130      0.000813         0.358651        0.015330
# 6739       0.008255      0.003855         0.344079        0.019899
#
#      param_leaf_size param_n_jobs param_n_neighbors param_weights  \
# 6171             245           -1               210      distance
# 6455             255           -1               210      distance
# 6739             265           -1               210      distance
#
#                                                  params  split0_test_score  \
# 6171  {'leaf_size': 245, 'n_jobs': -1, 'n_neighbors'...           0.791407
# 6455  {'leaf_size': 255, 'n_jobs': -1, 'n_neighbors'...           0.791407
# 6739  {'leaf_size': 265, 'n_jobs': -1, 'n_neighbors'...           0.791407
#
#       split1_test_score  split2_test_score  split3_test_score  \
# 6171           0.746116           0.797691           0.767351
# 6455           0.746116           0.797691           0.767351
# 6739           0.746116           0.797691           0.767351
#
#       split4_test_score  mean_test_score  std_test_score  rank_test_score
# 6171           0.780981         0.776709        0.018428                1
# 6455           0.780981         0.776709        0.018428                1
# 6739           0.780981         0.776709        0.018428                1

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_validate

# Obtain X, y, and groups from the training dataset
X = gemaps_shuffled_df.drop(columns=['target','file_id','actor_id', 'group'])
y = gemaps_shuffled_df.target
groups = gemaps_shuffled_df.group

logo = LeaveOneGroupOut()


# Load best parameters
file_path = os.path.join(output_path,'best_params','best_params_knn_gemaps_audio.sav')
best_params = pickle.load(open(file_path, 'rb'))
                   
clf = KNeighborsClassifier(**best_params)

scores = cross_validate(X=X, y=y,
                        estimator           = clf,
                        scoring             = ['roc_auc_ovo_weighted'],
                        cv                  = logo.split(X=X,groups=groups),
                        verbose             = 1,
                        n_jobs              = -1
                       )

print('AUC_avg (validation):', np.mean(scores['test_roc_auc_ovo_weighted']))
print('AUC_std (validation):', np.std(scores['test_roc_auc_ovo_weighted']))

# Confusion matrix
plot_save_conf_matrix(X         = X,
                      y         = y,
                      cv        = logo.split(X=X,groups=groups),
                      clf       = clf,
                      title     = 'kNN Normalized Confusion Matrix (Audio GeMAPS Validation Set)',
                      file_name = 'conf_mat_knn_gemaps_audio.svg'
                     )
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.7s finished
# AUC_avg (validation): 0.776709368442149
# AUC_std (validation): 0.018428436958196785

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# ### eGeMAPS

# %%
from sklearn.tree import DecisionTreeClassifier

# Obtain X, y, and groups from the training dataset
X = egemaps_shuffled_df.drop(columns=['target','file_id','actor_id', 'group'])
y = egemaps_shuffled_df.target
groups = egemaps_shuffled_df.group
n_groups = len(groups.unique())


# Define parameters to evaluate
criterion_values         = ['gini', 'entropy']
splitter_values          = ['best', 'random']
max_depth_values         = np.arange(5, 55, 5).tolist()
min_samples_split_values = np.linspace(0.1, 1.0, 10, endpoint=True)
min_samples_leaf_values  = np.linspace(0.1, 0.5, 5, endpoint=True)
max_features_values      = [int(x) for x in np.linspace(1, len(X.columns), num = 18)] #list(range(1,len(X.columns)))
parameters      = {'criterion': criterion_values,
                   'splitter': splitter_values,
                   'max_depth': max_depth_values,
                   'min_samples_split': min_samples_split_values,
                   'min_samples_leaf': min_samples_leaf_values,
                   'max_features': max_features_values,
                   'class_weight': ['balanced'],
                   'random_state': [seed]
                  }

dt = DecisionTreeClassifier()
logo = LeaveOneGroupOut()

# Reduce the number of possible combinations by randomly resampling to 5000 combinations
clf = RandomizedSearchCV(estimator           = dt, 
                         param_distributions = parameters,
                         scoring             = 'roc_auc_ovo_weighted',
                         cv                  = logo.split(X=X,groups=groups),
                         verbose             = 1,
                         random_state        = seed,
                         n_iter              = 5000,
                         n_jobs              = -1
                         )
clf.fit(X,y)
print(clf.best_estimator_)

# Store results in a DataFrame and then save them as csv
results_df = pd.DataFrame(clf.cv_results_)
results_df.to_csv(os.path.join(output_path,'results','res_tree_'+str(n_groups)+'_logocv_egemaps_audio.csv'), index=None, header=True)

# Save best parameters to disk
file_path = os.path.join(output_path,'best_params','best_params_tree_egemaps_audio.sav')
pickle.dump(clf.best_params_, open(file_path, 'wb'))

# Save the best model to disk
file_path = os.path.join(output_path,'models','mod_tree_egemaps_audio.sav')
pickle.dump(clf.best_estimator_, open(file_path, 'wb'))
# Out:
# Fitting 5 folds for each of 5000 candidates, totalling 25000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:   33.6s
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed:   59.4s
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 2442 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 3192 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 4042 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 4992 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 6042 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 7192 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 8442 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 9792 tasks      | elapsed: 12.0min
# [Parallel(n_jobs=-1)]: Done 11242 tasks      | elapsed: 13.7min
# [Parallel(n_jobs=-1)]: Done 12792 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=-1)]: Done 14442 tasks      | elapsed: 17.7min
# [Parallel(n_jobs=-1)]: Done 16192 tasks      | elapsed: 19.8min
# [Parallel(n_jobs=-1)]: Done 18042 tasks      | elapsed: 22.1min
# [Parallel(n_jobs=-1)]: Done 19992 tasks      | elapsed: 24.4min
# [Parallel(n_jobs=-1)]: Done 22042 tasks      | elapsed: 27.0min
# [Parallel(n_jobs=-1)]: Done 24192 tasks      | elapsed: 29.6min
# [Parallel(n_jobs=-1)]: Done 25000 out of 25000 | elapsed: 30.6min finished
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight='balanced',
#                        criterion='entropy', max_depth=50, max_features=52,
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=0.1,
#                        min_samples_split=0.1, min_weight_fraction_leaf=0.0,
#                        presort='deprecated', random_state=27, splitter='best')

# %%
results_df.sort_values(by="rank_test_score").head(3)
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 4273       0.078240      0.005539         0.273237        0.004454
# 1284       0.076409      0.002820         0.274662        0.006854
# 4265       0.074281      0.004352         0.277661        0.014198
#
#      param_splitter param_random_state param_min_samples_split  \
# 4273           best                 27                     0.2
# 1284           best                 27                     0.2
# 4265           best                 27                     0.2
#
#      param_min_samples_leaf param_max_features param_max_depth  ...  \
# 4273                    0.1                 52              40  ...
# 1284                    0.1                 52              10  ...
# 4265                    0.1                 52              50  ...
#
#      param_class_weight                                             params  \
# 4273           balanced  {'splitter': 'best', 'random_state': 27, 'min_...
# 1284           balanced  {'splitter': 'best', 'random_state': 27, 'min_...
# 4265           balanced  {'splitter': 'best', 'random_state': 27, 'min_...
#
#      split0_test_score  split1_test_score  split2_test_score  \
# 4273          0.720595           0.659904           0.712814
# 1284          0.720595           0.659904           0.712814
# 4265          0.720595           0.659904           0.712814
#
#       split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 4273            0.69565           0.720835         0.701959        0.022934
# 1284            0.69565           0.720835         0.701959        0.022934
# 4265            0.69565           0.720835         0.701959        0.022934
#
#       rank_test_score
# 4273                1
# 1284                1
# 4265                1
#
# [3 rows x 21 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_validate

# Obtain X, y, and groups from the training dataset
X = egemaps_shuffled_df.drop(columns=['target','file_id','actor_id', 'group'])
y = egemaps_shuffled_df.target
groups = egemaps_shuffled_df.group

logo = LeaveOneGroupOut()


# Load best parameters
file_path = os.path.join(output_path,'best_params','best_params_tree_egemaps_audio.sav')
best_params = pickle.load(open(file_path, 'rb'))
                   
clf = DecisionTreeClassifier(**best_params)

scores = cross_validate(X=X, y=y,
                        estimator           = clf,
                        scoring             = ['roc_auc_ovo_weighted'],
                        cv                  = logo.split(X=X,groups=groups),
                        verbose             = 1,
                        n_jobs              = -1
                       )

print('AUC_avg (validation):', np.mean(scores['test_roc_auc_ovo_weighted']))
print('AUC_std (validation):', np.std(scores['test_roc_auc_ovo_weighted']))

# Confusion matrix
plot_save_conf_matrix(X         = X,
                      y         = y,
                      cv        = logo.split(X=X,groups=groups),
                      clf       = clf,
                      title     = 'Decision Tree Normalized Confusion Matrix (Audio eGeMAPS Validation Set)',
                      file_name = 'conf_mat_tree_egemaps_audio.svg'
                     )
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.7s finished
# AUC_avg (validation): 0.7019594963123043
# AUC_std (validation): 0.022934022567140812

# %% [markdown]
# ### GeMAPS

# %%
from sklearn.tree import DecisionTreeClassifier

# Obtain X, y, and groups from the training dataset
X = gemaps_shuffled_df.drop(columns=['target','file_id','actor_id', 'group'])
y = gemaps_shuffled_df.target
groups = gemaps_shuffled_df.group
n_groups = len(groups.unique())


# Define parameters to evaluate
criterion_values         = ['gini', 'entropy']
splitter_values          = ['best', 'random']
max_depth_values         = np.arange(5, 55, 5).tolist()
min_samples_split_values = np.linspace(0.1, 1.0, 10, endpoint=True)
min_samples_leaf_values  = np.linspace(0.1, 0.5, 5, endpoint=True)
max_features_values      = [int(x) for x in np.linspace(1, len(X.columns), num = 18)] #list(range(1,len(X.columns)))
parameters      = {'criterion': criterion_values,
                   'splitter': splitter_values,
                   'max_depth': max_depth_values,
                   'min_samples_split': min_samples_split_values,
                   'min_samples_leaf': min_samples_leaf_values,
                   'max_features': max_features_values,
                   'class_weight': ['balanced'],
                   'random_state': [seed]
                  }

dt = DecisionTreeClassifier()
logo = LeaveOneGroupOut()

# Reduce the number of possible combinations by randomly resampling to 5000 combinations
clf = RandomizedSearchCV(estimator           = dt, 
                         param_distributions = parameters,
                         scoring             = 'roc_auc_ovo_weighted',
                         cv                  = logo.split(X=X,groups=groups),
                         verbose             = 1,
                         random_state        = seed,
                         n_iter              = 5000,
                         n_jobs              = -1
                         )
clf.fit(X,y)
print(clf.best_estimator_)

# Store results in a DataFrame and then save them as csv
results_df = pd.DataFrame(clf.cv_results_)
results_df.to_csv(os.path.join(output_path,'results','res_tree_'+str(n_groups)+'_logocv_gemaps_audio.csv'), index=None, header=True)

# Save best parameters to disk
file_path = os.path.join(output_path,'best_params','best_params_tree_gemaps_audio.sav')
pickle.dump(clf.best_params_, open(file_path, 'wb'))

# Save the best model to disk
file_path = os.path.join(output_path,'models','mod_tree_gemaps_audio.sav')
pickle.dump(clf.best_estimator_, open(file_path, 'wb'))
# Out:
# Fitting 5 folds for each of 5000 candidates, totalling 25000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed:   57.5s
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 2442 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 3192 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 4042 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 4992 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 6042 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 7192 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=-1)]: Done 8442 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 9792 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=-1)]: Done 11242 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=-1)]: Done 12792 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done 14442 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done 16192 tasks      | elapsed: 19.4min
# [Parallel(n_jobs=-1)]: Done 18042 tasks      | elapsed: 21.7min
# [Parallel(n_jobs=-1)]: Done 19992 tasks      | elapsed: 24.0min
# [Parallel(n_jobs=-1)]: Done 22042 tasks      | elapsed: 26.5min
# [Parallel(n_jobs=-1)]: Done 24192 tasks      | elapsed: 29.0min
# [Parallel(n_jobs=-1)]: Done 25000 out of 25000 | elapsed: 30.0min finished
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight='balanced',
#                        criterion='entropy', max_depth=50, max_features=22,
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=0.1,
#                        min_samples_split=0.2, min_weight_fraction_leaf=0.0,
#                        presort='deprecated', random_state=27, splitter='best')

# %%
results_df.sort_values(by="rank_test_score").head(3)
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 4216       0.033768      0.004090         0.287777        0.008432
# 1629       0.021565      0.000837         0.277369        0.005807
# 1579       0.021367      0.001042         0.284743        0.009844
#
#      param_splitter param_random_state param_min_samples_split  \
# 4216           best                 27                     0.2
# 1629           best                 27                     0.1
# 1579           best                 27                     0.2
#
#      param_min_samples_leaf param_max_features param_max_depth  ...  \
# 4216                    0.1                 22              50  ...
# 1629                    0.1                 44              15  ...
# 1579                    0.1                 44              35  ...
#
#      param_class_weight                                             params  \
# 4216           balanced  {'splitter': 'best', 'random_state': 27, 'min_...
# 1629           balanced  {'splitter': 'best', 'random_state': 27, 'min_...
# 1579           balanced  {'splitter': 'best', 'random_state': 27, 'min_...
#
#      split0_test_score  split1_test_score  split2_test_score  \
# 4216          0.746479           0.688512           0.720286
# 1629          0.709215           0.665986           0.718879
# 1579          0.709215           0.665986           0.718879
#
#       split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 4216           0.648187           0.711277         0.702948        0.033082
# 1629           0.699580           0.709157         0.700563        0.018334
# 1579           0.699580           0.709157         0.700563        0.018334
#
#       rank_test_score
# 4216                1
# 1629                2
# 1579                2
#
# [3 rows x 21 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_validate

# Obtain X, y, and groups from the training dataset
X = gemaps_shuffled_df.drop(columns=['target','file_id','actor_id', 'group'])
y = gemaps_shuffled_df.target
groups = gemaps_shuffled_df.group

logo = LeaveOneGroupOut()


# Load best parameters
file_path = os.path.join(output_path,'best_params','best_params_tree_gemaps_audio.sav')
best_params = pickle.load(open(file_path, 'rb'))
                   
clf = DecisionTreeClassifier(**best_params)

scores = cross_validate(X=X, y=y,
                        estimator           = clf,
                        scoring             = ['roc_auc_ovo_weighted'],
                        cv                  = logo.split(X=X,groups=groups),
                        verbose             = 1,
                        n_jobs              = -1
                       )

print('AUC_avg (validation):', np.mean(scores['test_roc_auc_ovo_weighted']))
print('AUC_std (validation):', np.std(scores['test_roc_auc_ovo_weighted']))

# Confusion matrix
plot_save_conf_matrix(X         = X,
                      y         = y,
                      cv        = logo.split(X=X,groups=groups),
                      clf       = clf,
                      title     = 'Decision Tree Normalized Confusion Matrix (Audio GeMAPS Validation Set)',
                      file_name = 'conf_mat_tree_gemaps_audio.svg'
                     )
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.6s finished
# AUC_avg (validation): 0.7029481835873341
# AUC_std (validation): 0.03308207326130565

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### eGeMAPS

# %%
from sklearn.ensemble import RandomForestClassifier

# Obtain X, y, and groups from the training dataset
X = egemaps_shuffled_df.drop(columns=['target','file_id','actor_id', 'group'])
y = egemaps_shuffled_df.target
groups = egemaps_shuffled_df.group
n_groups = len(groups.unique())


# Define parameters to evaluate
n_estimators_values      = [int(x) for x in np.linspace(10, 500, num = 100)]#np.arange(100, 810, 10).tolist()
criterion_values         = ['gini']
class_weight_values      = ['balanced']
max_features_values      = ['auto', 'sqrt']
max_depth_values         = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth_values.append(None)
min_samples_split_values = [2, 5, 10]
min_samples_leaf_values  = [1, 2, 4]
bootstrap_values         = [True, False]
parameters      = {'n_estimators': n_estimators_values,
                   'criterion': criterion_values,
                   'max_features': max_features_values,
                   'max_depth': max_depth_values,
                   'min_samples_split': min_samples_split_values,
                   'min_samples_leaf': min_samples_leaf_values,
                   'bootstrap': bootstrap_values,
                   'random_state': [seed],
                   'class_weight': class_weight_values,
                   'n_jobs': [-1]
                  }

rf = RandomForestClassifier()
logo = LeaveOneGroupOut()

# Reduce the number of possible combinations by randomly resampling to 5000 combinations
clf = RandomizedSearchCV(estimator           = rf, 
                         param_distributions = parameters,
                         scoring             = 'roc_auc_ovo_weighted',
                         cv                  = logo.split(X=X,groups=groups),
                         verbose             = 1,
                         n_iter              = 5000,
                         random_state        = seed,
                         n_jobs              = -1
                        )
clf.fit(X,y)
print(clf.best_estimator_)

# Store results in a DataFrame and then save them as csv
results_df = pd.DataFrame(clf.cv_results_)
results_df.to_csv(os.path.join(output_path,'results','res_rf_'+str(n_groups)+'_logocv_egemaps_audio.csv'), index=None, header=True)

# Save best parameters to disk
file_path = os.path.join(output_path,'best_params','best_params_rf_egemaps_audio.sav')
pickle.dump(clf.best_params_, open(file_path, 'wb'))

# Save the best model to disk
file_path = os.path.join(output_path,'models','mod_rf_egemaps_audio.sav')
pickle.dump(clf.best_estimator_, open(file_path, 'wb'))
# Out:
# Fitting 5 folds for each of 5000 candidates, totalling 25000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   53.4s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed: 14.7min
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed: 23.3min
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed: 34.4min
# [Parallel(n_jobs=-1)]: Done 2442 tasks      | elapsed: 46.8min
# [Parallel(n_jobs=-1)]: Done 3192 tasks      | elapsed: 59.6min
# [Parallel(n_jobs=-1)]: Done 4042 tasks      | elapsed: 73.7min
# [Parallel(n_jobs=-1)]: Done 4992 tasks      | elapsed: 90.2min
# [Parallel(n_jobs=-1)]: Done 6042 tasks      | elapsed: 106.0min
# [Parallel(n_jobs=-1)]: Done 7192 tasks      | elapsed: 124.0min
# [Parallel(n_jobs=-1)]: Done 8442 tasks      | elapsed: 143.1min
# [Parallel(n_jobs=-1)]: Done 9792 tasks      | elapsed: 163.4min
# [Parallel(n_jobs=-1)]: Done 11242 tasks      | elapsed: 186.7min
# [Parallel(n_jobs=-1)]: Done 12792 tasks      | elapsed: 212.3min
# [Parallel(n_jobs=-1)]: Done 14442 tasks      | elapsed: 238.3min
# [Parallel(n_jobs=-1)]: Done 16192 tasks      | elapsed: 265.1min
# [Parallel(n_jobs=-1)]: Done 18042 tasks      | elapsed: 293.4min
# [Parallel(n_jobs=-1)]: Done 19992 tasks      | elapsed: 324.5min
# [Parallel(n_jobs=-1)]: Done 22042 tasks      | elapsed: 357.6min
# [Parallel(n_jobs=-1)]: Done 24192 tasks      | elapsed: 392.7min
# [Parallel(n_jobs=-1)]: Done 25000 out of 25000 | elapsed: 406.4min finished
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=10, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=4, min_samples_split=5,
#                        min_weight_fraction_leaf=0.0, n_estimators=470,
#                        n_jobs=-1, oob_score=False, random_state=27, verbose=0,
#                        warm_start=False)

# %%
results_df.sort_values(by="rank_test_score").head(3)
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 4167       4.272253      0.121785         0.707933        0.080972
# 4417       4.363859      0.145605         0.649879        0.123425
# 1893       3.645988      0.087675         0.725149        0.032784
#
#      param_random_state param_n_jobs param_n_estimators  \
# 4167                 27           -1                470
# 4417                 27           -1                490
# 1893                 27           -1                405
#
#      param_min_samples_split param_min_samples_leaf param_max_features  ...  \
# 4167                       5                      4               auto  ...
# 4417                       5                      4               sqrt  ...
# 1893                       5                      4               auto  ...
#
#      param_bootstrap                                             params  \
# 4167            True  {'random_state': 27, 'n_jobs': -1, 'n_estimato...
# 4417            True  {'random_state': 27, 'n_jobs': -1, 'n_estimato...
# 1893            True  {'random_state': 27, 'n_jobs': -1, 'n_estimato...
#
#      split0_test_score split1_test_score split2_test_score  split3_test_score  \
# 4167          0.821960          0.775003          0.808774           0.770995
# 4417          0.820819          0.775288          0.808665           0.771475
# 1893          0.820689          0.773200          0.810210           0.771696
#
#       split4_test_score  mean_test_score  std_test_score  rank_test_score
# 4167           0.812610         0.797868        0.020793                1
# 4417           0.812753         0.797800        0.020353                2
# 1893           0.812857         0.797730        0.020934                3
#
# [3 rows x 23 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_validate

# Obtain X, y, and groups from the training dataset
X = egemaps_shuffled_df.drop(columns=['target','file_id','actor_id', 'group'])
y = egemaps_shuffled_df.target
groups = egemaps_shuffled_df.group

logo = LeaveOneGroupOut()


# Load best parameters
file_path = os.path.join(output_path,'best_params','best_params_rf_egemaps_audio.sav')
best_params = pickle.load(open(file_path, 'rb'))
                   
clf = RandomForestClassifier(**best_params)

scores = cross_validate(X=X, y=y,
                        estimator           = clf,
                        scoring             = ['roc_auc_ovo_weighted'],
                        cv                  = logo.split(X=X,groups=groups),
                        verbose             = 1,
                        n_jobs              = -1
                       )

print('AUC_avg (validation):', np.mean(scores['test_roc_auc_ovo_weighted']))
print('AUC_std (validation):', np.std(scores['test_roc_auc_ovo_weighted']))

# Confusion matrix
plot_save_conf_matrix(X         = X,
                      y         = y,
                      cv        = logo.split(X=X,groups=groups),
                      clf       = clf,
                      title     = 'Random Forest Normalized Confusion Matrix (Audio eGeMAPS Validation Set)',
                      file_name = 'conf_mat_rf_egemaps_audio.svg'
                     )
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    9.2s finished
# AUC_avg (validation): 0.7978684542935038
# AUC_std (validation): 0.020792630738836783

# %% [markdown]
# ### GeMAPS

# %%
from sklearn.ensemble import RandomForestClassifier

# Obtain X, y, and groups from the training dataset
X = gemaps_shuffled_df.drop(columns=['target','file_id','actor_id', 'group'])
y = gemaps_shuffled_df.target
groups = gemaps_shuffled_df.group
n_groups = len(groups.unique())


# Define parameters to evaluate
n_estimators_values      = [int(x) for x in np.linspace(10, 500, num = 100)]#np.arange(100, 810, 10).tolist()
criterion_values         = ['gini']
class_weight_values      = ['balanced']
max_features_values      = ['auto', 'sqrt']
max_depth_values         = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth_values.append(None)
min_samples_split_values = [2, 5, 10]
min_samples_leaf_values  = [1, 2, 4]
bootstrap_values         = [True, False]
parameters      = {'n_estimators': n_estimators_values,
                   'criterion': criterion_values,
                   'max_features': max_features_values,
                   'max_depth': max_depth_values,
                   'min_samples_split': min_samples_split_values,
                   'min_samples_leaf': min_samples_leaf_values,
                   'bootstrap': bootstrap_values,
                   'random_state': [seed],
                   'class_weight': class_weight_values,
                   'n_jobs': [-1]
                  }

rf = RandomForestClassifier()
logo = LeaveOneGroupOut()

# Reduce the number of possible combinations by randomly resampling to 5000 combinations
clf = RandomizedSearchCV(estimator           = rf, 
                         param_distributions = parameters,
                         scoring             = 'roc_auc_ovo_weighted',
                         cv                  = logo.split(X=X,groups=groups),
                         verbose             = 1,
                         n_iter              = 5000,
                         random_state        = seed,
                         n_jobs              = -1
                        )
clf.fit(X,y)
print(clf.best_estimator_)

# Store results in a DataFrame and then save them as csv
results_df = pd.DataFrame(clf.cv_results_)
results_df.to_csv(os.path.join(output_path,'results','res_rf_'+str(n_groups)+'_logocv_gemaps_audio.csv'), index=None, header=True)

# Save best parameters to disk
file_path = os.path.join(output_path,'best_params','best_params_rf_gemaps_audio.sav')
pickle.dump(clf.best_params_, open(file_path, 'wb'))

# Save the best model to disk
file_path = os.path.join(output_path,'models','mod_rf_gemaps_audio.sav')
pickle.dump(clf.best_estimator_, open(file_path, 'wb'))
# Out:
# Fitting 5 folds for each of 5000 candidates, totalling 25000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   36.1s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed: 16.9min
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed: 24.5min
# [Parallel(n_jobs=-1)]: Done 2442 tasks      | elapsed: 33.0min
# [Parallel(n_jobs=-1)]: Done 3192 tasks      | elapsed: 43.5min
# [Parallel(n_jobs=-1)]: Done 4042 tasks      | elapsed: 55.4min
# [Parallel(n_jobs=-1)]: Done 4992 tasks      | elapsed: 68.7min
# [Parallel(n_jobs=-1)]: Done 6042 tasks      | elapsed: 82.1min
# [Parallel(n_jobs=-1)]: Done 7192 tasks      | elapsed: 97.4min
# [Parallel(n_jobs=-1)]: Done 8442 tasks      | elapsed: 113.7min
# [Parallel(n_jobs=-1)]: Done 9792 tasks      | elapsed: 130.9min
# [Parallel(n_jobs=-1)]: Done 11242 tasks      | elapsed: 150.4min
# [Parallel(n_jobs=-1)]: Done 12792 tasks      | elapsed: 172.1min
# [Parallel(n_jobs=-1)]: Done 14442 tasks      | elapsed: 194.1min
# [Parallel(n_jobs=-1)]: Done 16192 tasks      | elapsed: 216.8min
# [Parallel(n_jobs=-1)]: Done 18042 tasks      | elapsed: 240.4min
# [Parallel(n_jobs=-1)]: Done 19992 tasks      | elapsed: 266.7min
# [Parallel(n_jobs=-1)]: Done 22042 tasks      | elapsed: 294.9min
# [Parallel(n_jobs=-1)]: Done 24192 tasks      | elapsed: 324.6min
# [Parallel(n_jobs=-1)]: Done 25000 out of 25000 | elapsed: 335.7min finished
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=10, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=4, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=346,
#                        n_jobs=-1, oob_score=False, random_state=27, verbose=0,
#                        warm_start=False)

# %%
results_df.sort_values(by="rank_test_score").head(3)
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 4907       2.680842      0.153937         0.526579        0.109593
# 4602       2.506783      0.206179         0.594856        0.138320
# 2976       2.276611      0.159245         0.663766        0.209809
#
#      param_random_state param_n_jobs param_n_estimators  \
# 4907                 27           -1                346
# 4602                 27           -1                326
# 2976                 27           -1                321
#
#      param_min_samples_split param_min_samples_leaf param_max_features  ...  \
# 4907                      10                      4               auto  ...
# 4602                      10                      4               sqrt  ...
# 2976                      10                      4               sqrt  ...
#
#      param_bootstrap                                             params  \
# 4907            True  {'random_state': 27, 'n_jobs': -1, 'n_estimato...
# 4602            True  {'random_state': 27, 'n_jobs': -1, 'n_estimato...
# 2976            True  {'random_state': 27, 'n_jobs': -1, 'n_estimato...
#
#      split0_test_score split1_test_score split2_test_score  split3_test_score  \
# 4907          0.812857          0.778737          0.811601           0.773745
# 4602          0.811832          0.778141          0.812646           0.773874
# 2976          0.812338          0.777894          0.812363           0.773900
#
#       split4_test_score  mean_test_score  std_test_score  rank_test_score
# 4907           0.818511         0.799090        0.018867                1
# 4602           0.818277         0.798954        0.018915                2
# 2976           0.818212         0.798942        0.018979                3
#
# [3 rows x 23 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_validate

# Obtain X, y, and groups from the training dataset
X = gemaps_shuffled_df.drop(columns=['target','file_id','actor_id', 'group'])
y = gemaps_shuffled_df.target
groups = gemaps_shuffled_df.group

logo = LeaveOneGroupOut()


# Load best parameters
file_path = os.path.join(output_path,'best_params','best_params_rf_gemaps_audio.sav')
best_params = pickle.load(open(file_path, 'rb'))
                   
clf = RandomForestClassifier(**best_params)

scores = cross_validate(X=X, y=y,
                        estimator           = clf,
                        scoring             = ['roc_auc_ovo_weighted'],
                        cv                  = logo.split(X=X,groups=groups),
                        verbose             = 1,
                        n_jobs              = -1
                       )

print('AUC_avg (validation):', np.mean(scores['test_roc_auc_ovo_weighted']))
print('AUC_std (validation):', np.std(scores['test_roc_auc_ovo_weighted']))

# Confusion matrix
plot_save_conf_matrix(X         = X,
                      y         = y,
                      cv        = logo.split(X=X,groups=groups),
                      clf       = clf,
                      title     = 'Random Forest Normalized Confusion Matrix (Audio GeMAPS Validation Set)',
                      file_name = 'conf_mat_rf_gemaps_audio.svg'
                     )
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    6.7s finished
# AUC_avg (validation): 0.7990901622390661
# AUC_std (validation): 0.018867068255502703
