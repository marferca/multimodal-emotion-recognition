# %% [markdown]
# # Early Fusion: Model Interpretation

# %% [markdown]
# ## Setup

# %%
import os
from glob import glob
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import sklearn as sk
import pickle
import copy

# %% [markdown]
# ### Paths

# %%
input_path = '../../../2.data_preparation/out/'
output_path = '../out/'
# Global configuration path
glob_conf_path = '../../../config/global_config_paper.py'

# %% [markdown]
# ### Load global variables

# %%
exec(open(glob_conf_path).read())

# %% [markdown]
# ### Load, prepare, and fuse data

# %% [markdown]
# #### Load

# %%
train_video_df = pd.read_csv(os.path.join(input_path, 'video', 'video_data_intensity_train.csv'))
train_audio_df = pd.read_csv(os.path.join(input_path, 'audio', 'egemaps', 'audio_data_egemaps_train.csv'))

# %% [markdown]
# #### Fuse data

# %%
# Fuse training data (audio + video)
train_audio_id_df_tmp = train_audio_df.drop(columns=['target','actor_id','group'])              # Drop target, actor_id, and group from the audio dataframe, since they are already in the video dataframe
train_df = train_audio_id_df_tmp.merge(train_video_df, how='left', on='file_id')                # Merge on file_id
train_df = train_df[[c for c in train_df if c not in ['file_id', 'actor_id', 'group','target']]
                    + ['file_id', 'actor_id', 'group','target']]                                # Reorder columns so file_id, actor_id, and target are at the end of the dataframe
train_df
# Out:
#       F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                              0.579782
# 1                              0.393945
# 2                              0.487920
# 3                              0.415525
# 4                              0.578382
# ...                                 ...
# 1254                           0.455030
# 1255                           0.220083
# 1256                           0.270762
# 1257                           0.450948
# 1258                           0.349244
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                   0.276111
# 1                                   0.343674
# 2                                   0.288303
# 3                                   0.320765
# 4                                   0.277224
# ...                                      ...
# 1254                                0.051548
# 1255                                0.513768
# 1256                                0.520014
# 1257                                0.089263
# 1258                                0.336031
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                       0.533631
# 1                                       0.384970
# 2                                       0.466380
# 3                                       0.357067
# 4                                       0.455800
# ...                                          ...
# 1254                                    0.459465
# 1255                                    0.031770
# 1256                                    0.024084
# 1257                                    0.419079
# 1258                                    0.397092
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                       0.596311
# 1                                       0.423466
# 2                                       0.452395
# 3                                       0.355146
# 4                                       0.559710
# ...                                          ...
# 1254                                    0.432665
# 1255                                    0.317742
# 1256                                    0.363869
# 1257                                    0.440764
# 1258                                    0.381677
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                       0.632179
# 1                                       0.446001
# 2                                       0.584362
# 3                                       0.490685
# 4                                       0.627945
# ...                                          ...
# 1254                                    0.428898
# 1255                                    0.347561
# 1256                                    0.372689
# 1257                                    0.442042
# 1258                                    0.380470
#
#       F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                     0.209500
# 1                                     0.147274
# 2                                     0.226165
# 3                                     0.233617
# 4                                     0.291699
# ...                                        ...
# 1254                                  0.042556
# 1255                                  0.422764
# 1256                                  0.462329
# 1257                                  0.104093
# 1258                                  0.052991
#
#       F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# 0                                        0.178389
# 1                                        0.282919
# 2                                        0.321936
# 3                                        0.187911
# 4                                        0.210346
# ...                                           ...
# 1254                                     0.136981
# 1255                                     0.358086
# 1256                                     0.259245
# 1257                                     0.162826
# 1258                                     0.227318
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  \
# 0                                          0.032262
# 1                                          0.175538
# 2                                          0.164298
# 3                                          0.038932
# 4                                          0.112102
# ...                                             ...
# 1254                                       0.009610
# 1255                                       0.306875
# 1256                                       0.118235
# 1257                                       0.065396
# 1258                                       0.087805
#
#       F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope  \
# 0                                         0.261604
# 1                                         0.267522
# 2                                         0.311106
# 3                                         0.222829
# 4                                         0.258617
# ...                                            ...
# 1254                                      0.209519
# 1255                                      0.228330
# 1256                                      0.245574
# 1257                                      0.205408
# 1258                                      0.235091
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope  ...  AU45_r_stddevNorm  \
# 0                                           0.070276  ...           0.363398
# 1                                           0.068505  ...           0.584047
# 2                                           0.203101  ...           0.380347
# 3                                           0.040867  ...           0.303059
# 4                                           0.044221  ...           0.255539
# ...                                              ...  ...                ...
# 1254                                        0.008897  ...           0.358930
# 1255                                        0.014988  ...           0.507585
# 1256                                        0.060586  ...           0.551471
# 1257                                        0.005887  ...           0.358960
# 1258                                        0.048350  ...           0.429621
#
#       AU45_r_percentile20.0  AU45_r_percentile50.0  AU45_r_percentile80.0  \
# 0                       0.0               0.007299               0.092857
# 1                       0.0               0.007299               0.057143
# 2                       0.0               0.029197               0.039286
# 3                       0.0               0.014599               0.035714
# 4                       0.0               0.058394               0.064286
# ...                     ...                    ...                    ...
# 1254                    0.0               0.000000               0.569286
# 1255                    0.0               0.021898               0.107143
# 1256                    0.0               0.007299               0.078571
# 1257                    0.0               0.000000               0.328571
# 1258                    0.0               0.000000               0.425000
#
#       AU45_r_iqr60_80-20  AU45_r_numPeaks  file_id  actor_id  group  target
# 0               0.092857         0.258065        0         1      4       1
# 1               0.057143         0.161290        1         1      4       1
# 2               0.039286         0.096774        2         1      4       1
# 3               0.035714         0.129032        3         1      4       1
# 4               0.064286         0.225806        4         1      4       1
# ...                  ...              ...      ...       ...    ...     ...
# 1254            0.569286         0.161290     1255        10      5      17
# 1255            0.107143         0.258065     1256        10      5      17
# 1256            0.078571         0.322581     1257        10      5      17
# 1257            0.328571         0.225806     1258        10      5      17
# 1258            0.425000         0.225806     1259        10      5      17
#
# [1259 rows x 211 columns]

# %% [markdown]
# ## Model interpretation

# %%
# Get features
feat = list(train_df.drop(columns=['file_id', 'actor_id', 'group','target']))


# Load the model from disk
file_path = os.path.join(output_path,'aus_egemaps','models','pipeline_early_fusion_clf_elastic_net.sav')
clf = pickle.load(open(file_path, 'rb'))
coef_df = pd.DataFrame(clf.coef_, index=list(emotion_id_to_emotion_num.keys()), columns=feat).T

# Plot results
sns.set_style({'ytick.left': True})
plt.figure(figsize=(30,70))
sns.heatmap(coef_df, annot=True, annot_kws={"size": 11}, fmt='.2f', cmap=conf_cmap, cbar_kws={"aspect": 45})
plt.xlabel('Emotion ID')
plt.ylabel('Feature')
plt.savefig(os.path.join(output_path,'aus_egemaps','others','report_early_fusion_multimodal_classifier_feature_importance.svg'), bbox_inches = 'tight')
plt.title('Early Fusion (Multimodal Classifier): Logistic Regression Coefficients as Feature Importance Scores per Emotion')
plt.savefig(os.path.join(output_path,'aus_egemaps','others','early_fusion_multimodal_classifier_feature_importance.svg'), bbox_inches = 'tight')
plt.show()

sns.set_style({'ytick.left': False})
