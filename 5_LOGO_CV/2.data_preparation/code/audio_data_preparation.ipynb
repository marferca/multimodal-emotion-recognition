# %% [markdown]
# # Audio Data Preparation

# %%
import os
from glob import glob
from pathlib import Path
from tqdm import tqdm

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import sklearn as sk

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Paths

# %%
# Audio features dataset
input_path_egemaps = '../../1.feature_extraction/out/audio/egemaps/'
input_path_gemaps = '../../1.feature_extraction/out/audio/gemaps/'

# CSV output
output_path_egemaps = '../out/audio/egemaps/'
output_path_gemaps = '../out/audio/gemaps/'

# Global configuration path
glob_conf_path = '../../config/global_config_paper.py'

# %% [markdown]
# ### Load global variables

# %%
exec(open(glob_conf_path).read())

# %% [markdown]
# ## Concatenate all csv files

# %%
csv_paths_egemaps = glob(input_path_egemaps +  '*.csv')
print("Files found (eGeMAPS):",len(csv_paths_egemaps))

csv_paths_gemaps = glob(input_path_gemaps +  '*.csv')
print("Files found (GeMAPS):",len(csv_paths_gemaps))
# Out:
# Files found (eGeMAPS): 1260
# Files found (GeMAPS): 1260

# %% [markdown]
# ### Concatenating eGeMAPS features

# %%
df_egemaps = pd.DataFrame()

for f in tqdm(csv_paths_egemaps):
    df_tmp = pd.read_csv(f,sep=';')
    
    file_name  = Path(f).stem      # Get file name without extention
    actor_id   = file_name[14:16]  # Get actor number id
    emotion_id = file_name[16:19]  # Get emotion id
    _          = file_name[19:]    # Get number after emotion
    
    df_tmp["actor_id"]   = actor_id                          # Add actor id to the df
    df_tmp["emotion_id"] = emotion_id                        # Add emotion id to the df
    df_tmp["emotion"]    = emotion_id_to_emotion[emotion_id] # Add emotion to the df
    df_tmp["file"]       = Path(f).name                      # Add file name to the df 
    
    df_egemaps = df_egemaps.append(df_tmp)

df_egemaps["file_id"] = pd.factorize(df_egemaps.file, sort=True)[0] # Add a column with a file id (number)
df_egemaps.sort_values(by=['file_id'], ignore_index=True, inplace=True)

df_egemaps.to_csv(output_path_egemaps + 'audio_data_step_0_egemaps_full_dataset.csv', index=None, header=True)

# Save mapping from video file to file id
df_files_egemaps = df_egemaps[['file_id','file']].drop_duplicates()
df_files_egemaps.to_csv(output_path_egemaps + 'audio_data_step_0_egemaps_file_id_mapping.csv', index=None, header=True)
# Out:
# 100%|██████████| 1260/1260 [00:19<00:00, 65.60it/s]

# %%
df_egemaps
# Out:
#       frameIndex  frameTime  F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0              0        0.0                           38.28683
# 1              0        0.0                           30.48631
# 2              0        0.0                           34.43089
# 3              0        0.0                           31.39212
# 4              0        0.0                           38.22805
# ...          ...        ...                                ...
# 1255           0        0.0                           33.05034
# 1256           0        0.0                           23.18843
# 1257           0        0.0                           25.31570
# 1258           0        0.0                           32.87899
# 1259           0        0.0                           28.60996
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                   0.174699
# 1                                   0.215761
# 2                                   0.182109
# 3                                   0.201838
# 4                                   0.175376
# ...                                      ...
# 1255                                0.038219
# 1256                                0.319137
# 1257                                0.322934
# 1258                                0.061140
# 1259                                0.211116
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                       35.24582
# 1                                       28.91192
# 2                                       32.38050
# 3                                       27.72310
# 4                                       31.92973
# ...                                          ...
# 1255                                    32.08590
# 1256                                    13.86350
# 1257                                    13.53601
# 1258                                    30.36520
# 1259                                    29.42843
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                       40.81793
# 1                                       32.82476
# 2                                       34.16259
# 3                                       29.66535
# 4                                       39.12532
# ...                                          ...
# 1255                                    33.25019
# 1256                                    27.93560
# 1257                                    30.06873
# 1258                                    33.62474
# 1259                                    30.89225
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                       43.58985
# 1                                       34.89528
# 2                                       41.35676
# 3                                       36.98203
# 4                                       43.39213
# ...                                          ...
# 1255                                    34.09655
# 1256                                    30.29812
# 1257                                    31.47161
# 1258                                    34.71041
# 1259                                    31.83498
#
#       F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                     8.344032
# 1                                     5.983360
# 2                                     8.976254
# 3                                     9.258934
# 4                                    11.462400
# ...                                        ...
# 1255                                  2.010654
# 1256                                 16.434620
# 1257                                 17.935600
# 1258                                  4.345211
# 1259                                  2.406549
#
#       F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# 0                                       119.49430
# 1                                       351.93540
# 2                                       438.69700
# 3                                       140.66670
# 4                                       190.55580
# ...                                           ...
# 1255                                     27.41553
# 1256                                    519.08320
# 1257                                    299.29100
# 1258                                     84.88749
# 1259                                    228.29680
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  ...  \
# 0                                          65.28829  ...
# 1                                         355.23310  ...
# 2                                         332.48540  ...
# 3                                          78.78543  ...
# 4                                         226.85900  ...
# ...                                             ...  ...
# 1255                                       19.44676  ...
# 1256                                      621.01690  ...
# 1257                                      239.26910  ...
# 1258                                      132.34040  ...
# 1259                                      177.68950  ...
#
#       MeanVoicedSegmentLengthSec  StddevVoicedSegmentLengthSec  \
# 0                       0.266000                      0.240217
# 1                       0.383333                      0.182635
# 2                       0.274000                      0.184673
# 3                       0.282500                      0.153195
# 4                       0.610000                      0.657926
# ...                          ...                           ...
# 1255                    0.446667                      0.133000
# 1256                    0.176667                      0.185927
# 1257                    0.172941                      0.220794
# 1258                    0.440000                      0.158955
# 1259                    0.215000                      0.202546
#
#       MeanUnvoicedSegmentLength  StddevUnvoicedSegmentLength  \
# 0                      0.066000                     0.063119
# 1                      0.080000                     0.000000
# 2                      0.070000                     0.035590
# 3                      0.063333                     0.028674
# 4                      0.063333                     0.041899
# ...                         ...                          ...
# 1255                   0.120000                     0.090921
# 1256                   0.106429                     0.068620
# 1257                   0.126875                     0.105695
# 1258                   0.185000                     0.191638
# 1259                   0.100000                     0.058797
#
#       equivalentSoundLevel_dBp  actor_id  emotion_id    emotion  \
# 0                    -24.38904        01         amu  amusement
# 1                    -24.52001        01         amu  amusement
# 2                    -24.13003        01         amu  amusement
# 3                    -23.08461        01         amu  amusement
# 4                    -23.62944        01         amu  amusement
# ...                        ...       ...         ...        ...
# 1255                 -25.23524        10         tri    sadness
# 1256                 -23.72039        10         tri    sadness
# 1257                 -23.15614        10         tri    sadness
# 1258                 -24.59979        10         tri    sadness
# 1259                 -24.50074        10         tri    sadness
#
#                              file  file_id
# 0      egemaps_norm_A01amu111.csv        0
# 1      egemaps_norm_A01amu112.csv        1
# 2      egemaps_norm_A01amu121.csv        2
# 3      egemaps_norm_A01amu124.csv        3
# 4      egemaps_norm_A01amu133.csv        4
# ...                           ...      ...
# 1255   egemaps_norm_A10tri216.csv     1255
# 1256   egemaps_norm_A10tri317.csv     1256
# 1257   egemaps_norm_A10tri319.csv     1257
# 1258  egemaps_norm_A10tri4118.csv     1258
# 1259   egemaps_norm_A10tri419.csv     1259
#
# [1260 rows x 95 columns]

# %% [markdown]
# ### Concatenating GeMAPS features

# %%
df_gemaps = pd.DataFrame()

for f in tqdm(csv_paths_gemaps):
    df_tmp = pd.read_csv(f, sep=';')
    
    file_name  = Path(f).stem      # Get file name without extention
    actor_id   = file_name[13:15]  # Get actor number id
    emotion_id = file_name[15:18]  # Get emotion id
    _          = file_name[18:]    # Get number after emotion
    
    df_tmp["actor_id"]   = actor_id                          # Add actor id to the df
    df_tmp["emotion_id"] = emotion_id                        # Add emotion id to the df
    df_tmp["emotion"]    = emotion_id_to_emotion[emotion_id] # Add emotion to the df
    df_tmp["file"]       = Path(f).name                      # Add file name to the df 
    
    df_gemaps = df_gemaps.append(df_tmp)

df_gemaps["file_id"] = pd.factorize(df_gemaps.file, sort=True)[0] # Add a column with a file id (number)
df_gemaps.sort_values(by=['file_id'], ignore_index=True, inplace=True)
df_gemaps.to_csv(output_path_gemaps + 'audio_data_step_0_gemaps_full_dataset.csv', index=None, header=True)

# Save mapping from video file to file id
df_files_gemaps = df_gemaps[['file_id','file']].drop_duplicates()
df_files_gemaps.to_csv(output_path_gemaps + 'audio_data_step_0_gemaps_file_id_mapping.csv', index=None, header=True)
# Out:
# 100%|██████████| 1260/1260 [00:18<00:00, 68.43it/s]

# %%
df_gemaps
# Out:
#       frameIndex  frameTime  F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0              0        0.0                           38.28683
# 1              0        0.0                           30.48631
# 2              0        0.0                           34.43089
# 3              0        0.0                           31.39212
# 4              0        0.0                           38.22805
# ...          ...        ...                                ...
# 1255           0        0.0                           33.05034
# 1256           0        0.0                           23.18843
# 1257           0        0.0                           25.31570
# 1258           0        0.0                           32.87899
# 1259           0        0.0                           28.60996
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                   0.174699
# 1                                   0.215761
# 2                                   0.182109
# 3                                   0.201838
# 4                                   0.175376
# ...                                      ...
# 1255                                0.038219
# 1256                                0.319137
# 1257                                0.322934
# 1258                                0.061140
# 1259                                0.211116
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                       35.24582
# 1                                       28.91192
# 2                                       32.38050
# 3                                       27.72310
# 4                                       31.92973
# ...                                          ...
# 1255                                    32.08590
# 1256                                    13.86350
# 1257                                    13.53601
# 1258                                    30.36520
# 1259                                    29.42843
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                       40.81793
# 1                                       32.82476
# 2                                       34.16259
# 3                                       29.66535
# 4                                       39.12532
# ...                                          ...
# 1255                                    33.25019
# 1256                                    27.93560
# 1257                                    30.06873
# 1258                                    33.62474
# 1259                                    30.89225
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                       43.58985
# 1                                       34.89528
# 2                                       41.35676
# 3                                       36.98203
# 4                                       43.39213
# ...                                          ...
# 1255                                    34.09655
# 1256                                    30.29812
# 1257                                    31.47161
# 1258                                    34.71041
# 1259                                    31.83498
#
#       F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                     8.344032
# 1                                     5.983360
# 2                                     8.976254
# 3                                     9.258934
# 4                                    11.462400
# ...                                        ...
# 1255                                  2.010654
# 1256                                 16.434620
# 1257                                 17.935600
# 1258                                  4.345211
# 1259                                  2.406549
#
#       F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# 0                                       119.49430
# 1                                       351.93540
# 2                                       438.69700
# 3                                       140.66670
# 4                                       190.55580
# ...                                           ...
# 1255                                     27.41553
# 1256                                    519.08320
# 1257                                    299.29100
# 1258                                     84.88749
# 1259                                    228.29680
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  ...  \
# 0                                          65.28829  ...
# 1                                         355.23310  ...
# 2                                         332.48540  ...
# 3                                          78.78543  ...
# 4                                         226.85900  ...
# ...                                             ...  ...
# 1255                                       19.44676  ...
# 1256                                      621.01690  ...
# 1257                                      239.26910  ...
# 1258                                      132.34040  ...
# 1259                                      177.68950  ...
#
#       VoicedSegmentsPerSec  MeanVoicedSegmentLengthSec  \
# 0                 2.824859                    0.266000
# 1                 2.290076                    0.383333
# 2                 2.941177                    0.274000
# 3                 2.877698                    0.282500
# 4                 1.456311                    0.610000
# ...                    ...                         ...
# 1255              1.704545                    0.446667
# 1256              3.355705                    0.176667
# 1257              3.195489                    0.172941
# 1258              1.408451                    0.440000
# 1259              2.777778                    0.215000
#
#       StddevVoicedSegmentLengthSec  MeanUnvoicedSegmentLength  \
# 0                         0.240217                   0.066000
# 1                         0.182635                   0.080000
# 2                         0.184673                   0.070000
# 3                         0.153195                   0.063333
# 4                         0.657926                   0.063333
# ...                            ...                        ...
# 1255                      0.133000                   0.120000
# 1256                      0.185927                   0.106429
# 1257                      0.220794                   0.126875
# 1258                      0.158955                   0.185000
# 1259                      0.202546                   0.100000
#
#       StddevUnvoicedSegmentLength  actor_id  emotion_id    emotion  \
# 0                        0.063119        01         amu  amusement
# 1                        0.000000        01         amu  amusement
# 2                        0.035590        01         amu  amusement
# 3                        0.028674        01         amu  amusement
# 4                        0.041899        01         amu  amusement
# ...                           ...       ...         ...        ...
# 1255                     0.090921        10         tri    sadness
# 1256                     0.068620        10         tri    sadness
# 1257                     0.105695        10         tri    sadness
# 1258                     0.191638        10         tri    sadness
# 1259                     0.058797        10         tri    sadness
#
#                             file  file_id
# 0      gemaps_norm_A01amu111.csv        0
# 1      gemaps_norm_A01amu112.csv        1
# 2      gemaps_norm_A01amu121.csv        2
# 3      gemaps_norm_A01amu124.csv        3
# 4      gemaps_norm_A01amu133.csv        4
# ...                          ...      ...
# 1255   gemaps_norm_A10tri216.csv     1255
# 1256   gemaps_norm_A10tri317.csv     1256
# 1257   gemaps_norm_A10tri319.csv     1257
# 1258  gemaps_norm_A10tri4118.csv     1258
# 1259   gemaps_norm_A10tri419.csv     1259
#
# [1260 rows x 69 columns]

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### Data inspection before data cleaning

# %% [markdown]
# In this section we will inspect the dataset. For this porpuse, we will focus on the following elements:
#
# * Number of files per emotion

# %% [markdown]
# #### eGeMAPS

# %%
# Load csv
df = pd.read_csv(output_path_egemaps + 'audio_data_step_0_egemaps_full_dataset.csv')

print('Files per emotion before data cleaning')
files_per_emotion_count_original = df[['emotion_id','file']].groupby(['emotion_id']).file.nunique()
print('Total number of files: {}'.format(files_per_emotion_count_original.sum()))
print(files_per_emotion_count_original)
plt.figure(figsize=(15,5))
sns.barplot(files_per_emotion_count_original.index, files_per_emotion_count_original.values, saturation=sns_saturation, color=blue_rgb)
plt.title('Files per emotion before data cleaning (eGeMAPS)')
plt.xlabel('Emotion ID')
plt.ylabel('Number of Files')
plt.show()
print()
# Out:
# Files per emotion before data cleaning
# Total number of files: 1260
# emotion_id
# adm    30
# amu    90
# att    30
# col    90
# deg    30
# des    90
# fie    90
# hon    30
# inq    90
# int    90
# irr    90
# joi    90
# mep    30
# peu    90
# pla    90
# sou    90
# sur    30
# tri    90
# Name: file, dtype: int64

# %% [markdown]
# #### GeMAPS

# %%
# Load csv
df = pd.read_csv(output_path_gemaps + 'audio_data_step_0_gemaps_full_dataset.csv')

print('Files per emotion before data cleaning')
files_per_emotion_count_original = df[['emotion_id','file']].groupby(['emotion_id']).file.nunique()
print('Total number of files: {}'.format(files_per_emotion_count_original.sum()))
print(files_per_emotion_count_original)
plt.figure(figsize=(15,5))
sns.barplot(files_per_emotion_count_original.index, files_per_emotion_count_original.values, saturation=sns_saturation, color=blue_rgb)
plt.title('Files per emotion before data cleaning (GeMAPS)')
plt.xlabel('Emotion ID')
plt.ylabel('Number of Files')
plt.show()
print()
# Out:
# Files per emotion before data cleaning
# Total number of files: 1260
# emotion_id
# adm    30
# amu    90
# att    30
# col    90
# deg    30
# des    90
# fie    90
# hon    30
# inq    90
# int    90
# irr    90
# joi    90
# mep    30
# peu    90
# pla    90
# sou    90
# sur    30
# tri    90
# Name: file, dtype: int64

# %% [markdown]
# #### Look for null values

# %%
df_egemaps.replace(r'^\s*$', np.nan, regex=True)
print("Are there any null values in the eGeMAPS dataset?",df_egemaps.isnull().values.any())

df_gemaps.replace(r'^\s*$', np.nan, regex=True)
print("Are there any null values in the GeMAPS dataset?",df_gemaps.isnull().values.any())
# Out:
# Are there any null values in the eGeMAPS dataset? False
# Are there any null values in the GeMAPS dataset? False

# %% [markdown]
# ### Remove some instances
# One file was deleted after the video data cleaning, hence the corresponding audio instance needs to be dropped from the audio dataset.

# %% [markdown]
# #### eGeMAPS

# %%
df_egemaps[df_egemaps['file'] == 'egemaps_norm_A05int132.csv' ]
# Out:
#      frameIndex  frameTime  F0semitoneFrom27.5Hz_sma3nz_amean  \
# 563           0        0.0                           19.15213
#
#      F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 563                                0.198332
#
#      F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 563                                    17.26127
#
#      F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 563                                    18.71836
#
#      F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 563                                    23.14464
#
#      F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 563                                  5.883369
#
#      F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# 563                                     19.44014
#
#      F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  ...  \
# 563                                       12.68781  ...
#
#      MeanVoicedSegmentLengthSec  StddevVoicedSegmentLengthSec  \
# 563                     0.17125                       0.34783
#
#      MeanUnvoicedSegmentLength  StddevUnvoicedSegmentLength  \
# 563                    0.05375                     0.040601
#
#      equivalentSoundLevel_dBp  actor_id  emotion_id   emotion  \
# 563                  -27.3362        05         int  interest
#
#                            file  file_id
# 563  egemaps_norm_A05int132.csv      563
#
# [1 rows x 95 columns]

# %%
egemaps_before_cleaning_df = pd.read_csv(output_path_egemaps + 'audio_data_step_0_egemaps_full_dataset.csv')
egemaps_after_cleaning_df  = egemaps_before_cleaning_df.drop(egemaps_before_cleaning_df[egemaps_before_cleaning_df['file'] == 'egemaps_norm_A05int132.csv'].index)
egemaps_after_cleaning_df.to_csv(output_path_egemaps + 'audio_data_step_1_egemaps_data_cleaning.csv', index=None, header=True)
print('Number of files before data cleaning (eGeMAPS): {}'.format(len(egemaps_before_cleaning_df)))
print('Number of files after data cleaning (eGeMAPS): {}'.format(len(egemaps_after_cleaning_df)))


gemaps_before_cleaning_df = pd.read_csv(output_path_gemaps + 'audio_data_step_0_gemaps_full_dataset.csv')
gemaps_after_cleaning_df = gemaps_before_cleaning_df.drop(gemaps_before_cleaning_df[gemaps_before_cleaning_df['file'] == 'gemaps_norm_A05int132.csv'].index)
gemaps_after_cleaning_df.to_csv(output_path_gemaps + 'audio_data_step_1_gemaps_data_cleaning.csv', index=None, header=True)
print('Number of files before data cleaning (GeMAPS): {}'.format(len(gemaps_before_cleaning_df)))
print('Number of files after data cleaning (GeMAPS): {}'.format(len(gemaps_after_cleaning_df)))
# Out:
# Number of files before data cleaning (eGeMAPS): 1260
# Number of files after data cleaning (eGeMAPS): 1259
# Number of files before data cleaning (GeMAPS): 1260
# Number of files after data cleaning (GeMAPS): 1259

# %%
gemaps_after_cleaning_df
# Out:
#       frameIndex  frameTime  F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0              0        0.0                           38.28683
# 1              0        0.0                           30.48631
# 2              0        0.0                           34.43089
# 3              0        0.0                           31.39212
# 4              0        0.0                           38.22805
# ...          ...        ...                                ...
# 1255           0        0.0                           33.05034
# 1256           0        0.0                           23.18843
# 1257           0        0.0                           25.31570
# 1258           0        0.0                           32.87899
# 1259           0        0.0                           28.60996
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                   0.174699
# 1                                   0.215761
# 2                                   0.182109
# 3                                   0.201838
# 4                                   0.175376
# ...                                      ...
# 1255                                0.038219
# 1256                                0.319137
# 1257                                0.322934
# 1258                                0.061140
# 1259                                0.211116
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                       35.24582
# 1                                       28.91192
# 2                                       32.38050
# 3                                       27.72310
# 4                                       31.92973
# ...                                          ...
# 1255                                    32.08590
# 1256                                    13.86350
# 1257                                    13.53601
# 1258                                    30.36520
# 1259                                    29.42843
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                       40.81793
# 1                                       32.82476
# 2                                       34.16259
# 3                                       29.66535
# 4                                       39.12532
# ...                                          ...
# 1255                                    33.25019
# 1256                                    27.93560
# 1257                                    30.06873
# 1258                                    33.62474
# 1259                                    30.89225
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                       43.58985
# 1                                       34.89528
# 2                                       41.35676
# 3                                       36.98203
# 4                                       43.39213
# ...                                          ...
# 1255                                    34.09655
# 1256                                    30.29812
# 1257                                    31.47161
# 1258                                    34.71041
# 1259                                    31.83498
#
#       F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                     8.344032
# 1                                     5.983360
# 2                                     8.976254
# 3                                     9.258934
# 4                                    11.462400
# ...                                        ...
# 1255                                  2.010654
# 1256                                 16.434620
# 1257                                 17.935600
# 1258                                  4.345211
# 1259                                  2.406549
#
#       F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# 0                                       119.49430
# 1                                       351.93540
# 2                                       438.69700
# 3                                       140.66670
# 4                                       190.55580
# ...                                           ...
# 1255                                     27.41553
# 1256                                    519.08320
# 1257                                    299.29100
# 1258                                     84.88749
# 1259                                    228.29680
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  ...  \
# 0                                          65.28829  ...
# 1                                         355.23310  ...
# 2                                         332.48540  ...
# 3                                          78.78543  ...
# 4                                         226.85900  ...
# ...                                             ...  ...
# 1255                                       19.44676  ...
# 1256                                      621.01690  ...
# 1257                                      239.26910  ...
# 1258                                      132.34040  ...
# 1259                                      177.68950  ...
#
#       VoicedSegmentsPerSec  MeanVoicedSegmentLengthSec  \
# 0                 2.824859                    0.266000
# 1                 2.290076                    0.383333
# 2                 2.941177                    0.274000
# 3                 2.877698                    0.282500
# 4                 1.456311                    0.610000
# ...                    ...                         ...
# 1255              1.704545                    0.446667
# 1256              3.355705                    0.176667
# 1257              3.195489                    0.172941
# 1258              1.408451                    0.440000
# 1259              2.777778                    0.215000
#
#       StddevVoicedSegmentLengthSec  MeanUnvoicedSegmentLength  \
# 0                         0.240217                   0.066000
# 1                         0.182635                   0.080000
# 2                         0.184673                   0.070000
# 3                         0.153195                   0.063333
# 4                         0.657926                   0.063333
# ...                            ...                        ...
# 1255                      0.133000                   0.120000
# 1256                      0.185927                   0.106429
# 1257                      0.220794                   0.126875
# 1258                      0.158955                   0.185000
# 1259                      0.202546                   0.100000
#
#       StddevUnvoicedSegmentLength  actor_id  emotion_id    emotion  \
# 0                        0.063119         1         amu  amusement
# 1                        0.000000         1         amu  amusement
# 2                        0.035590         1         amu  amusement
# 3                        0.028674         1         amu  amusement
# 4                        0.041899         1         amu  amusement
# ...                           ...       ...         ...        ...
# 1255                     0.090921        10         tri    sadness
# 1256                     0.068620        10         tri    sadness
# 1257                     0.105695        10         tri    sadness
# 1258                     0.191638        10         tri    sadness
# 1259                     0.058797        10         tri    sadness
#
#                             file  file_id
# 0      gemaps_norm_A01amu111.csv        0
# 1      gemaps_norm_A01amu112.csv        1
# 2      gemaps_norm_A01amu121.csv        2
# 3      gemaps_norm_A01amu124.csv        3
# 4      gemaps_norm_A01amu133.csv        4
# ...                          ...      ...
# 1255   gemaps_norm_A10tri216.csv     1255
# 1256   gemaps_norm_A10tri317.csv     1256
# 1257   gemaps_norm_A10tri319.csv     1257
# 1258  gemaps_norm_A10tri4118.csv     1258
# 1259   gemaps_norm_A10tri419.csv     1259
#
# [1259 rows x 69 columns]

# %% [markdown]
# ### Data inspection after data cleaning

# %% [markdown]
# #### eGeMAPS

# %%
# Load csv
df = pd.read_csv(output_path_egemaps + 'audio_data_step_1_egemaps_data_cleaning.csv')

print('Files per emotion after data cleaning')
files_per_emotion_count_original = df[['emotion_id','file']].groupby(['emotion_id']).file.nunique()
print('Total number of files: {}'.format(files_per_emotion_count_original.sum()))
print(files_per_emotion_count_original)
plt.figure(figsize=(15,5))
sns.barplot(files_per_emotion_count_original.index, files_per_emotion_count_original.values, saturation=sns_saturation, color=blue_rgb)
plt.title('Files per emotion after data cleaning (eGeMAPS)')
plt.xlabel('Emotion ID')
plt.ylabel('Number of Files')
plt.show()
print()
# Out:
# Files per emotion after data cleaning
# Total number of files: 1259
# emotion_id
# adm    30
# amu    90
# att    30
# col    90
# deg    30
# des    90
# fie    90
# hon    30
# inq    90
# int    89
# irr    90
# joi    90
# mep    30
# peu    90
# pla    90
# sou    90
# sur    30
# tri    90
# Name: file, dtype: int64

# %% [markdown]
# #### GeMAPS

# %%
# Load csv
df = pd.read_csv(output_path_gemaps + 'audio_data_step_1_gemaps_data_cleaning.csv')

print('Files per emotion after data cleaning')
files_per_emotion_count_original = df[['emotion_id','file']].groupby(['emotion_id']).file.nunique()
print('Total number of files: {}'.format(files_per_emotion_count_original.sum()))
print(files_per_emotion_count_original)
plt.figure(figsize=(15,5))
sns.barplot(files_per_emotion_count_original.index, files_per_emotion_count_original.values, saturation=sns_saturation, color=blue_rgb)
plt.title('Files per emotion after data cleaning (GeMAPS)')
plt.xlabel('Emotion ID')
plt.ylabel('Number of Files')
plt.show()
print()
# Out:
# Files per emotion after data cleaning
# Total number of files: 1259
# emotion_id
# adm    30
# amu    90
# att    30
# col    90
# deg    30
# des    90
# fie    90
# hon    30
# inq    90
# int    89
# irr    90
# joi    90
# mep    30
# peu    90
# pla    90
# sou    90
# sur    30
# tri    90
# Name: file, dtype: int64

# %% [markdown]
# ## Dimensionality reduction

# %% [markdown]
# In this section, we will reduce the dimensionality of our dataset by manually selecting relevant features for our sample (feature selection). But first, we will see what kinds of dimensions we have in the dataset.

# %%
df_egemaps = pd.read_csv(output_path_egemaps + 'audio_data_step_1_egemaps_data_cleaning.csv')
df_gemaps = pd.read_csv(output_path_gemaps + 'audio_data_step_1_gemaps_data_cleaning.csv')

df_egemaps = df_egemaps.drop(columns=['frameIndex', 'frameTime', 'emotion', 'file'])
df_gemaps = df_gemaps.drop(columns=['frameIndex', 'frameTime', 'emotion', 'file'])


df_egemaps.to_csv(output_path_egemaps + 'audio_data_step_2_egemaps_dimensionality_reduction.csv', index=None, header=True)
df_gemaps.to_csv(output_path_gemaps + 'audio_data_step_2_gemaps_dimensionality_reduction.csv', index=None, header=True)

# %%
df_egemaps
# Out:
#       F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                              38.28683
# 1                              30.48631
# 2                              34.43089
# 3                              31.39212
# 4                              38.22805
# ...                                 ...
# 1254                           33.05034
# 1255                           23.18843
# 1256                           25.31570
# 1257                           32.87899
# 1258                           28.60996
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                   0.174699
# 1                                   0.215761
# 2                                   0.182109
# 3                                   0.201838
# 4                                   0.175376
# ...                                      ...
# 1254                                0.038219
# 1255                                0.319137
# 1256                                0.322934
# 1257                                0.061140
# 1258                                0.211116
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                       35.24582
# 1                                       28.91192
# 2                                       32.38050
# 3                                       27.72310
# 4                                       31.92973
# ...                                          ...
# 1254                                    32.08590
# 1255                                    13.86350
# 1256                                    13.53601
# 1257                                    30.36520
# 1258                                    29.42843
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                       40.81793
# 1                                       32.82476
# 2                                       34.16259
# 3                                       29.66535
# 4                                       39.12532
# ...                                          ...
# 1254                                    33.25019
# 1255                                    27.93560
# 1256                                    30.06873
# 1257                                    33.62474
# 1258                                    30.89225
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                       43.58985
# 1                                       34.89528
# 2                                       41.35676
# 3                                       36.98203
# 4                                       43.39213
# ...                                          ...
# 1254                                    34.09655
# 1255                                    30.29812
# 1256                                    31.47161
# 1257                                    34.71041
# 1258                                    31.83498
#
#       F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                     8.344032
# 1                                     5.983360
# 2                                     8.976254
# 3                                     9.258934
# 4                                    11.462400
# ...                                        ...
# 1254                                  2.010654
# 1255                                 16.434620
# 1256                                 17.935600
# 1257                                  4.345211
# 1258                                  2.406549
#
#       F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# 0                                       119.49430
# 1                                       351.93540
# 2                                       438.69700
# 3                                       140.66670
# 4                                       190.55580
# ...                                           ...
# 1254                                     27.41553
# 1255                                    519.08320
# 1256                                    299.29100
# 1257                                     84.88749
# 1258                                    228.29680
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  \
# 0                                          65.28829
# 1                                         355.23310
# 2                                         332.48540
# 3                                          78.78543
# 4                                         226.85900
# ...                                             ...
# 1254                                       19.44676
# 1255                                      621.01690
# 1256                                      239.26910
# 1257                                      132.34040
# 1258                                      177.68950
#
#       F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope  \
# 0                                        115.02070
# 1                                        125.66140
# 2                                        204.02830
# 3                                         45.30075
# 4                                        109.65090
# ...                                            ...
# 1254                                      21.36834
# 1255                                      55.19181
# 1256                                      86.19820
# 1257                                      13.97614
# 1258                                      67.34826
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope  ...  \
# 0                                           99.92057  ...
# 1                                           97.40245  ...
# 2                                          288.77620  ...
# 3                                           58.10585  ...
# 4                                           62.87440  ...
# ...                                              ...  ...
# 1254                                        12.65029  ...
# 1255                                        21.31094  ...
# 1256                                        86.14408  ...
# 1257                                         8.37091  ...
# 1258                                        68.74584  ...
#
#       loudnessPeaksPerSec  VoicedSegmentsPerSec  MeanVoicedSegmentLengthSec  \
# 0                5.978261              2.824859                    0.266000
# 1                6.569343              2.290076                    0.383333
# 2                5.113636              2.941177                    0.274000
# 3                5.517241              2.877698                    0.282500
# 4                5.045871              1.456311                    0.610000
# ...                   ...                   ...                         ...
# 1254             3.867404              1.704545                    0.446667
# 1255             1.754386              3.355705                    0.176667
# 1256             1.675978              3.195489                    0.172941
# 1257             2.752294              1.408451                    0.440000
# 1258             3.167421              2.777778                    0.215000
#
#       StddevVoicedSegmentLengthSec  MeanUnvoicedSegmentLength  \
# 0                         0.240217                   0.066000
# 1                         0.182635                   0.080000
# 2                         0.184673                   0.070000
# 3                         0.153195                   0.063333
# 4                         0.657926                   0.063333
# ...                            ...                        ...
# 1254                      0.133000                   0.120000
# 1255                      0.185927                   0.106429
# 1256                      0.220794                   0.126875
# 1257                      0.158955                   0.185000
# 1258                      0.202546                   0.100000
#
#       StddevUnvoicedSegmentLength  equivalentSoundLevel_dBp  actor_id  \
# 0                        0.063119                 -24.38904         1
# 1                        0.000000                 -24.52001         1
# 2                        0.035590                 -24.13003         1
# 3                        0.028674                 -23.08461         1
# 4                        0.041899                 -23.62944         1
# ...                           ...                       ...       ...
# 1254                     0.090921                 -25.23524        10
# 1255                     0.068620                 -23.72039        10
# 1256                     0.105695                 -23.15614        10
# 1257                     0.191638                 -24.59979        10
# 1258                     0.058797                 -24.50074        10
#
#       emotion_id  file_id
# 0            amu        0
# 1            amu        1
# 2            amu        2
# 3            amu        3
# 4            amu        4
# ...          ...      ...
# 1254         tri     1255
# 1255         tri     1256
# 1256         tri     1257
# 1257         tri     1258
# 1258         tri     1259
#
# [1259 rows x 91 columns]

# %%
df_gemaps
# Out:
#       F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                              38.28683
# 1                              30.48631
# 2                              34.43089
# 3                              31.39212
# 4                              38.22805
# ...                                 ...
# 1254                           33.05034
# 1255                           23.18843
# 1256                           25.31570
# 1257                           32.87899
# 1258                           28.60996
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                   0.174699
# 1                                   0.215761
# 2                                   0.182109
# 3                                   0.201838
# 4                                   0.175376
# ...                                      ...
# 1254                                0.038219
# 1255                                0.319137
# 1256                                0.322934
# 1257                                0.061140
# 1258                                0.211116
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                       35.24582
# 1                                       28.91192
# 2                                       32.38050
# 3                                       27.72310
# 4                                       31.92973
# ...                                          ...
# 1254                                    32.08590
# 1255                                    13.86350
# 1256                                    13.53601
# 1257                                    30.36520
# 1258                                    29.42843
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                       40.81793
# 1                                       32.82476
# 2                                       34.16259
# 3                                       29.66535
# 4                                       39.12532
# ...                                          ...
# 1254                                    33.25019
# 1255                                    27.93560
# 1256                                    30.06873
# 1257                                    33.62474
# 1258                                    30.89225
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                       43.58985
# 1                                       34.89528
# 2                                       41.35676
# 3                                       36.98203
# 4                                       43.39213
# ...                                          ...
# 1254                                    34.09655
# 1255                                    30.29812
# 1256                                    31.47161
# 1257                                    34.71041
# 1258                                    31.83498
#
#       F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                     8.344032
# 1                                     5.983360
# 2                                     8.976254
# 3                                     9.258934
# 4                                    11.462400
# ...                                        ...
# 1254                                  2.010654
# 1255                                 16.434620
# 1256                                 17.935600
# 1257                                  4.345211
# 1258                                  2.406549
#
#       F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# 0                                       119.49430
# 1                                       351.93540
# 2                                       438.69700
# 3                                       140.66670
# 4                                       190.55580
# ...                                           ...
# 1254                                     27.41553
# 1255                                    519.08320
# 1256                                    299.29100
# 1257                                     84.88749
# 1258                                    228.29680
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  \
# 0                                          65.28829
# 1                                         355.23310
# 2                                         332.48540
# 3                                          78.78543
# 4                                         226.85900
# ...                                             ...
# 1254                                       19.44676
# 1255                                      621.01690
# 1256                                      239.26910
# 1257                                      132.34040
# 1258                                      177.68950
#
#       F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope  \
# 0                                        115.02070
# 1                                        125.66140
# 2                                        204.02830
# 3                                         45.30075
# 4                                        109.65090
# ...                                            ...
# 1254                                      21.36834
# 1255                                      55.19181
# 1256                                      86.19820
# 1257                                      13.97614
# 1258                                      67.34826
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope  ...  \
# 0                                           99.92057  ...
# 1                                           97.40245  ...
# 2                                          288.77620  ...
# 3                                           58.10585  ...
# 4                                           62.87440  ...
# ...                                              ...  ...
# 1254                                        12.65029  ...
# 1255                                        21.31094  ...
# 1256                                        86.14408  ...
# 1257                                         8.37091  ...
# 1258                                        68.74584  ...
#
#       slopeUV500-1500_sma3nz_amean  loudnessPeaksPerSec  VoicedSegmentsPerSec  \
# 0                        -0.011299             5.978261              2.824859
# 1                        -0.004146             6.569343              2.290076
# 2                        -0.008774             5.113636              2.941177
# 3                        -0.007155             5.517241              2.877698
# 4                        -0.012126             5.045871              1.456311
# ...                            ...                  ...                   ...
# 1254                     -0.004202             3.867404              1.704545
# 1255                     -0.003959             1.754386              3.355705
# 1256                     -0.003862             1.675978              3.195489
# 1257                     -0.005005             2.752294              1.408451
# 1258                     -0.003578             3.167421              2.777778
#
#       MeanVoicedSegmentLengthSec  StddevVoicedSegmentLengthSec  \
# 0                       0.266000                      0.240217
# 1                       0.383333                      0.182635
# 2                       0.274000                      0.184673
# 3                       0.282500                      0.153195
# 4                       0.610000                      0.657926
# ...                          ...                           ...
# 1254                    0.446667                      0.133000
# 1255                    0.176667                      0.185927
# 1256                    0.172941                      0.220794
# 1257                    0.440000                      0.158955
# 1258                    0.215000                      0.202546
#
#       MeanUnvoicedSegmentLength  StddevUnvoicedSegmentLength  actor_id  \
# 0                      0.066000                     0.063119         1
# 1                      0.080000                     0.000000         1
# 2                      0.070000                     0.035590         1
# 3                      0.063333                     0.028674         1
# 4                      0.063333                     0.041899         1
# ...                         ...                          ...       ...
# 1254                   0.120000                     0.090921        10
# 1255                   0.106429                     0.068620        10
# 1256                   0.126875                     0.105695        10
# 1257                   0.185000                     0.191638        10
# 1258                   0.100000                     0.058797        10
#
#       emotion_id  file_id
# 0            amu        0
# 1            amu        1
# 2            amu        2
# 3            amu        3
# 4            amu        4
# ...          ...      ...
# 1254         tri     1255
# 1255         tri     1256
# 1256         tri     1257
# 1257         tri     1258
# 1258         tri     1259
#
# [1259 rows x 65 columns]

# %% [markdown]
# ## Normalize training set
# There is no test set

# %%
egemaps_df = pd.read_csv(output_path_egemaps + 'audio_data_step_2_egemaps_dimensionality_reduction.csv')
gemaps_df = pd.read_csv(output_path_gemaps + 'audio_data_step_2_gemaps_dimensionality_reduction.csv')

# %%
egemaps_df
# Out:
#       F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                              38.28683
# 1                              30.48631
# 2                              34.43089
# 3                              31.39212
# 4                              38.22805
# ...                                 ...
# 1254                           33.05034
# 1255                           23.18843
# 1256                           25.31570
# 1257                           32.87899
# 1258                           28.60996
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                   0.174699
# 1                                   0.215761
# 2                                   0.182109
# 3                                   0.201838
# 4                                   0.175376
# ...                                      ...
# 1254                                0.038219
# 1255                                0.319137
# 1256                                0.322934
# 1257                                0.061140
# 1258                                0.211116
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                       35.24582
# 1                                       28.91192
# 2                                       32.38050
# 3                                       27.72310
# 4                                       31.92973
# ...                                          ...
# 1254                                    32.08590
# 1255                                    13.86350
# 1256                                    13.53601
# 1257                                    30.36520
# 1258                                    29.42843
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                       40.81793
# 1                                       32.82476
# 2                                       34.16259
# 3                                       29.66535
# 4                                       39.12532
# ...                                          ...
# 1254                                    33.25019
# 1255                                    27.93560
# 1256                                    30.06873
# 1257                                    33.62474
# 1258                                    30.89225
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                       43.58985
# 1                                       34.89528
# 2                                       41.35676
# 3                                       36.98203
# 4                                       43.39213
# ...                                          ...
# 1254                                    34.09655
# 1255                                    30.29812
# 1256                                    31.47161
# 1257                                    34.71041
# 1258                                    31.83498
#
#       F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                     8.344032
# 1                                     5.983360
# 2                                     8.976254
# 3                                     9.258934
# 4                                    11.462400
# ...                                        ...
# 1254                                  2.010654
# 1255                                 16.434620
# 1256                                 17.935600
# 1257                                  4.345211
# 1258                                  2.406549
#
#       F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# 0                                       119.49430
# 1                                       351.93540
# 2                                       438.69700
# 3                                       140.66670
# 4                                       190.55580
# ...                                           ...
# 1254                                     27.41553
# 1255                                    519.08320
# 1256                                    299.29100
# 1257                                     84.88749
# 1258                                    228.29680
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  \
# 0                                          65.28829
# 1                                         355.23310
# 2                                         332.48540
# 3                                          78.78543
# 4                                         226.85900
# ...                                             ...
# 1254                                       19.44676
# 1255                                      621.01690
# 1256                                      239.26910
# 1257                                      132.34040
# 1258                                      177.68950
#
#       F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope  \
# 0                                        115.02070
# 1                                        125.66140
# 2                                        204.02830
# 3                                         45.30075
# 4                                        109.65090
# ...                                            ...
# 1254                                      21.36834
# 1255                                      55.19181
# 1256                                      86.19820
# 1257                                      13.97614
# 1258                                      67.34826
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope  ...  \
# 0                                           99.92057  ...
# 1                                           97.40245  ...
# 2                                          288.77620  ...
# 3                                           58.10585  ...
# 4                                           62.87440  ...
# ...                                              ...  ...
# 1254                                        12.65029  ...
# 1255                                        21.31094  ...
# 1256                                        86.14408  ...
# 1257                                         8.37091  ...
# 1258                                        68.74584  ...
#
#       loudnessPeaksPerSec  VoicedSegmentsPerSec  MeanVoicedSegmentLengthSec  \
# 0                5.978261              2.824859                    0.266000
# 1                6.569343              2.290076                    0.383333
# 2                5.113636              2.941177                    0.274000
# 3                5.517241              2.877698                    0.282500
# 4                5.045871              1.456311                    0.610000
# ...                   ...                   ...                         ...
# 1254             3.867404              1.704545                    0.446667
# 1255             1.754386              3.355705                    0.176667
# 1256             1.675978              3.195489                    0.172941
# 1257             2.752294              1.408451                    0.440000
# 1258             3.167421              2.777778                    0.215000
#
#       StddevVoicedSegmentLengthSec  MeanUnvoicedSegmentLength  \
# 0                         0.240217                   0.066000
# 1                         0.182635                   0.080000
# 2                         0.184673                   0.070000
# 3                         0.153195                   0.063333
# 4                         0.657926                   0.063333
# ...                            ...                        ...
# 1254                      0.133000                   0.120000
# 1255                      0.185927                   0.106429
# 1256                      0.220794                   0.126875
# 1257                      0.158955                   0.185000
# 1258                      0.202546                   0.100000
#
#       StddevUnvoicedSegmentLength  equivalentSoundLevel_dBp  actor_id  \
# 0                        0.063119                 -24.38904         1
# 1                        0.000000                 -24.52001         1
# 2                        0.035590                 -24.13003         1
# 3                        0.028674                 -23.08461         1
# 4                        0.041899                 -23.62944         1
# ...                           ...                       ...       ...
# 1254                     0.090921                 -25.23524        10
# 1255                     0.068620                 -23.72039        10
# 1256                     0.105695                 -23.15614        10
# 1257                     0.191638                 -24.59979        10
# 1258                     0.058797                 -24.50074        10
#
#       emotion_id  file_id
# 0            amu        0
# 1            amu        1
# 2            amu        2
# 3            amu        3
# 4            amu        4
# ...          ...      ...
# 1254         tri     1255
# 1255         tri     1256
# 1256         tri     1257
# 1257         tri     1258
# 1258         tri     1259
#
# [1259 rows x 91 columns]

# %%
egemaps_df['emotion_id'].value_counts().sort_index()
# Out:
# adm    30
# amu    90
# att    30
# col    90
# deg    30
# des    90
# fie    90
# hon    30
# inq    90
# int    89
# irr    90
# joi    90
# mep    30
# peu    90
# pla    90
# sou    90
# sur    30
# tri    90
# Name: emotion_id, dtype: int64

# %%
gemaps_df
# Out:
#       F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                              38.28683
# 1                              30.48631
# 2                              34.43089
# 3                              31.39212
# 4                              38.22805
# ...                                 ...
# 1254                           33.05034
# 1255                           23.18843
# 1256                           25.31570
# 1257                           32.87899
# 1258                           28.60996
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                   0.174699
# 1                                   0.215761
# 2                                   0.182109
# 3                                   0.201838
# 4                                   0.175376
# ...                                      ...
# 1254                                0.038219
# 1255                                0.319137
# 1256                                0.322934
# 1257                                0.061140
# 1258                                0.211116
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                       35.24582
# 1                                       28.91192
# 2                                       32.38050
# 3                                       27.72310
# 4                                       31.92973
# ...                                          ...
# 1254                                    32.08590
# 1255                                    13.86350
# 1256                                    13.53601
# 1257                                    30.36520
# 1258                                    29.42843
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                       40.81793
# 1                                       32.82476
# 2                                       34.16259
# 3                                       29.66535
# 4                                       39.12532
# ...                                          ...
# 1254                                    33.25019
# 1255                                    27.93560
# 1256                                    30.06873
# 1257                                    33.62474
# 1258                                    30.89225
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                       43.58985
# 1                                       34.89528
# 2                                       41.35676
# 3                                       36.98203
# 4                                       43.39213
# ...                                          ...
# 1254                                    34.09655
# 1255                                    30.29812
# 1256                                    31.47161
# 1257                                    34.71041
# 1258                                    31.83498
#
#       F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                     8.344032
# 1                                     5.983360
# 2                                     8.976254
# 3                                     9.258934
# 4                                    11.462400
# ...                                        ...
# 1254                                  2.010654
# 1255                                 16.434620
# 1256                                 17.935600
# 1257                                  4.345211
# 1258                                  2.406549
#
#       F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# 0                                       119.49430
# 1                                       351.93540
# 2                                       438.69700
# 3                                       140.66670
# 4                                       190.55580
# ...                                           ...
# 1254                                     27.41553
# 1255                                    519.08320
# 1256                                    299.29100
# 1257                                     84.88749
# 1258                                    228.29680
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  \
# 0                                          65.28829
# 1                                         355.23310
# 2                                         332.48540
# 3                                          78.78543
# 4                                         226.85900
# ...                                             ...
# 1254                                       19.44676
# 1255                                      621.01690
# 1256                                      239.26910
# 1257                                      132.34040
# 1258                                      177.68950
#
#       F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope  \
# 0                                        115.02070
# 1                                        125.66140
# 2                                        204.02830
# 3                                         45.30075
# 4                                        109.65090
# ...                                            ...
# 1254                                      21.36834
# 1255                                      55.19181
# 1256                                      86.19820
# 1257                                      13.97614
# 1258                                      67.34826
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope  ...  \
# 0                                           99.92057  ...
# 1                                           97.40245  ...
# 2                                          288.77620  ...
# 3                                           58.10585  ...
# 4                                           62.87440  ...
# ...                                              ...  ...
# 1254                                        12.65029  ...
# 1255                                        21.31094  ...
# 1256                                        86.14408  ...
# 1257                                         8.37091  ...
# 1258                                        68.74584  ...
#
#       slopeUV500-1500_sma3nz_amean  loudnessPeaksPerSec  VoicedSegmentsPerSec  \
# 0                        -0.011299             5.978261              2.824859
# 1                        -0.004146             6.569343              2.290076
# 2                        -0.008774             5.113636              2.941177
# 3                        -0.007155             5.517241              2.877698
# 4                        -0.012126             5.045871              1.456311
# ...                            ...                  ...                   ...
# 1254                     -0.004202             3.867404              1.704545
# 1255                     -0.003959             1.754386              3.355705
# 1256                     -0.003862             1.675978              3.195489
# 1257                     -0.005005             2.752294              1.408451
# 1258                     -0.003578             3.167421              2.777778
#
#       MeanVoicedSegmentLengthSec  StddevVoicedSegmentLengthSec  \
# 0                       0.266000                      0.240217
# 1                       0.383333                      0.182635
# 2                       0.274000                      0.184673
# 3                       0.282500                      0.153195
# 4                       0.610000                      0.657926
# ...                          ...                           ...
# 1254                    0.446667                      0.133000
# 1255                    0.176667                      0.185927
# 1256                    0.172941                      0.220794
# 1257                    0.440000                      0.158955
# 1258                    0.215000                      0.202546
#
#       MeanUnvoicedSegmentLength  StddevUnvoicedSegmentLength  actor_id  \
# 0                      0.066000                     0.063119         1
# 1                      0.080000                     0.000000         1
# 2                      0.070000                     0.035590         1
# 3                      0.063333                     0.028674         1
# 4                      0.063333                     0.041899         1
# ...                         ...                          ...       ...
# 1254                   0.120000                     0.090921        10
# 1255                   0.106429                     0.068620        10
# 1256                   0.126875                     0.105695        10
# 1257                   0.185000                     0.191638        10
# 1258                   0.100000                     0.058797        10
#
#       emotion_id  file_id
# 0            amu        0
# 1            amu        1
# 2            amu        2
# 3            amu        3
# 4            amu        4
# ...          ...      ...
# 1254         tri     1255
# 1255         tri     1256
# 1256         tri     1257
# 1257         tri     1258
# 1258         tri     1259
#
# [1259 rows x 65 columns]

# %%
gemaps_df['emotion_id'].value_counts().sort_index()
# Out:
# adm    30
# amu    90
# att    30
# col    90
# deg    30
# des    90
# fie    90
# hon    30
# inq    90
# int    89
# irr    90
# joi    90
# mep    30
# peu    90
# pla    90
# sou    90
# sur    30
# tri    90
# Name: emotion_id, dtype: int64

# %%
from sklearn import preprocessing

# eGeMAPS
X = egemaps_df.drop(columns=['emotion_id','file_id','actor_id'])          # Get features from training set
min_max_scaler_egemaps = preprocessing.MinMaxScaler()                     # eGeMAPS min max scaler
X_scaled = min_max_scaler_egemaps.fit_transform(X)                        # Fit and transform features
X_scaled_df = pd.DataFrame(data=X_scaled, columns=X.columns.to_list())    # Create a dataframe from normalized features
metadata_df = egemaps_df[['emotion_id','actor_id','file_id']]
metadata_df = metadata_df.assign(target=metadata_df.loc[:,'emotion_id'].map(emotion_id_to_emotion_num).values)
metadata_df = metadata_df.drop(columns=['emotion_id'])
train_egemaps_scaled_df = pd.concat([X_scaled_df,metadata_df], axis=1)
#train_egemaps_scaled_df

# Train GeMAPS
X = gemaps_df.drop(columns=['emotion_id','file_id','actor_id'])           # Get features from training set
min_max_scaler_gemaps = preprocessing.MinMaxScaler()                      # GeMAPS min max scaler
X_scaled = min_max_scaler_gemaps.fit_transform(X)                         # Fit and transform features
X_scaled_df = pd.DataFrame(data=X_scaled, columns=X.columns.to_list())    # Create a dataframe from normalized features
metadata_df = gemaps_df[['emotion_id','actor_id','file_id']]
metadata_df = metadata_df.assign(target=metadata_df.loc[:,'emotion_id'].map(emotion_id_to_emotion_num).values)
metadata_df = metadata_df.drop(columns=['emotion_id'])
train_gemaps_scaled_df = pd.concat([X_scaled_df,metadata_df], axis=1)
#train_gemaps_scaled_df


# Save to csv
train_egemaps_scaled_df.to_csv(output_path_egemaps + 'audio_data_egemaps_train.csv', index=None, header=True)
train_gemaps_scaled_df.to_csv(output_path_gemaps + 'audio_data_gemaps_train.csv', index=None, header=True)

# %%
train_egemaps_scaled_df
# Out:
#       F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                              0.579782
# 1                              0.393945
# 2                              0.487920
# 3                              0.415525
# 4                              0.578382
# ...                                 ...
# 1254                           0.455030
# 1255                           0.220083
# 1256                           0.270762
# 1257                           0.450948
# 1258                           0.349244
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                   0.276111
# 1                                   0.343674
# 2                                   0.288303
# 3                                   0.320765
# 4                                   0.277224
# ...                                      ...
# 1254                                0.051548
# 1255                                0.513768
# 1256                                0.520014
# 1257                                0.089263
# 1258                                0.336031
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                       0.533631
# 1                                       0.384970
# 2                                       0.466380
# 3                                       0.357067
# 4                                       0.455800
# ...                                          ...
# 1254                                    0.459465
# 1255                                    0.031770
# 1256                                    0.024084
# 1257                                    0.419079
# 1258                                    0.397092
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                       0.596311
# 1                                       0.423466
# 2                                       0.452395
# 3                                       0.355146
# 4                                       0.559710
# ...                                          ...
# 1254                                    0.432665
# 1255                                    0.317742
# 1256                                    0.363869
# 1257                                    0.440764
# 1258                                    0.381677
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                       0.632179
# 1                                       0.446001
# 2                                       0.584362
# 3                                       0.490685
# 4                                       0.627945
# ...                                          ...
# 1254                                    0.428898
# 1255                                    0.347561
# 1256                                    0.372689
# 1257                                    0.442042
# 1258                                    0.380470
#
#       F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                     0.209500
# 1                                     0.147274
# 2                                     0.226165
# 3                                     0.233617
# 4                                     0.291699
# ...                                        ...
# 1254                                  0.042556
# 1255                                  0.422764
# 1256                                  0.462329
# 1257                                  0.104093
# 1258                                  0.052991
#
#       F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# 0                                        0.178389
# 1                                        0.282919
# 2                                        0.321936
# 3                                        0.187911
# 4                                        0.210346
# ...                                           ...
# 1254                                     0.136981
# 1255                                     0.358086
# 1256                                     0.259245
# 1257                                     0.162826
# 1258                                     0.227318
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  \
# 0                                          0.032262
# 1                                          0.175538
# 2                                          0.164298
# 3                                          0.038932
# 4                                          0.112102
# ...                                             ...
# 1254                                       0.009610
# 1255                                       0.306875
# 1256                                       0.118235
# 1257                                       0.065396
# 1258                                       0.087805
#
#       F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope  \
# 0                                         0.261604
# 1                                         0.267522
# 2                                         0.311106
# 3                                         0.222829
# 4                                         0.258617
# ...                                            ...
# 1254                                      0.209519
# 1255                                      0.228330
# 1256                                      0.245574
# 1257                                      0.205408
# 1258                                      0.235091
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope  ...  \
# 0                                           0.070276  ...
# 1                                           0.068505  ...
# 2                                           0.203101  ...
# 3                                           0.040867  ...
# 4                                           0.044221  ...
# ...                                              ...  ...
# 1254                                        0.008897  ...
# 1255                                        0.014988  ...
# 1256                                        0.060586  ...
# 1257                                        0.005887  ...
# 1258                                        0.048350  ...
#
#       loudnessPeaksPerSec  VoicedSegmentsPerSec  MeanVoicedSegmentLengthSec  \
# 0                0.718996              0.330578                    0.037114
# 1                0.792587              0.264558                    0.055237
# 2                0.611349              0.344937                    0.038350
# 3                0.661599              0.337101                    0.039662
# 4                0.602913              0.161629                    0.090247
# ...                   ...                   ...                         ...
# 1254             0.456192              0.192274                    0.065019
# 1255             0.193118              0.396111                    0.023316
# 1256             0.183356              0.376332                    0.022740
# 1257             0.317359              0.155720                    0.063989
# 1258             0.369043              0.324766                    0.029237
#
#       StddevVoicedSegmentLengthSec  MeanUnvoicedSegmentLength  \
# 0                         0.117179                   0.047826
# 1                         0.089090                   0.057971
# 2                         0.090084                   0.050725
# 3                         0.074729                   0.045894
# 4                         0.320940                   0.045894
# ...                            ...                        ...
# 1254                      0.064878                   0.086957
# 1255                      0.090696                   0.077122
# 1256                      0.107705                   0.091938
# 1257                      0.077539                   0.134058
# 1258                      0.098803                   0.072464
#
#       StddevUnvoicedSegmentLength  equivalentSoundLevel_dBp  actor_id  \
# 0                        0.088380                  0.731259         1
# 1                        0.000000                  0.725443         1
# 2                        0.049834                  0.742759         1
# 3                        0.040150                  0.789177         1
# 4                        0.058668                  0.764986         1
# ...                           ...                       ...       ...
# 1254                     0.127309                  0.693686        10
# 1255                     0.096082                  0.760948        10
# 1256                     0.147996                  0.786001        10
# 1257                     0.268334                  0.721901        10
# 1258                     0.082329                  0.726299        10
#
#       file_id  target
# 0           0       1
# 1           1       1
# 2           2       1
# 3           3       1
# 4           4       1
# ...       ...     ...
# 1254     1255      17
# 1255     1256      17
# 1256     1257      17
# 1257     1258      17
# 1258     1259      17
#
# [1259 rows x 91 columns]

# %% [markdown]
# ### Create groups for LOGO CV

# %%
import random

# Find random pairs of actors
random.seed(seed)
actors_1 = [2, 4, 5, 9, 10]
actors_2 = [1, 3, 6, 7, 8]
actors_2_shuffled = random.sample(actors_2, len(actors_2))

# Define groups
groups = {actors_1[0]: 1, actors_2_shuffled[0]: 1, # G1 = (A02, A07) (female, female)
          actors_1[1]: 2, actors_2_shuffled[1]: 2, # G2 = (A04, A06) (male, female)
          actors_1[2]: 3, actors_2_shuffled[2]: 3, # G3 = (A05, A03) (male, male)
          actors_1[3]: 4, actors_2_shuffled[3]: 4, # G4 = (A09, A01) (female, male)
          actors_1[4]: 5, actors_2_shuffled[4]: 5  # G5 = (A10, A08) (female, male)
         }
print(groups)

# Create a copy
train_egemaps_scaled_groups_df = train_egemaps_scaled_df.copy()
train_gemaps_scaled_groups_df = train_gemaps_scaled_df.copy()

# Insert group column
train_egemaps_scaled_groups_df['group'] = train_egemaps_scaled_groups_df['actor_id'].map(groups)
train_gemaps_scaled_groups_df['group'] = train_gemaps_scaled_groups_df['actor_id'].map(groups)

# Save to csv
train_egemaps_scaled_groups_df.to_csv(output_path_egemaps + 'audio_data_egemaps_train.csv', index=None, header=True)
train_gemaps_scaled_groups_df.to_csv(output_path_gemaps + 'audio_data_gemaps_train.csv', index=None, header=True)
# Out:
# {2: 1, 7: 1, 4: 2, 6: 2, 5: 3, 3: 3, 9: 4, 1: 4, 10: 5, 8: 5}

# %%
train_egemaps_scaled_groups_df
# Out:
#       F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                              0.579782
# 1                              0.393945
# 2                              0.487920
# 3                              0.415525
# 4                              0.578382
# ...                                 ...
# 1254                           0.455030
# 1255                           0.220083
# 1256                           0.270762
# 1257                           0.450948
# 1258                           0.349244
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                   0.276111
# 1                                   0.343674
# 2                                   0.288303
# 3                                   0.320765
# 4                                   0.277224
# ...                                      ...
# 1254                                0.051548
# 1255                                0.513768
# 1256                                0.520014
# 1257                                0.089263
# 1258                                0.336031
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                       0.533631
# 1                                       0.384970
# 2                                       0.466380
# 3                                       0.357067
# 4                                       0.455800
# ...                                          ...
# 1254                                    0.459465
# 1255                                    0.031770
# 1256                                    0.024084
# 1257                                    0.419079
# 1258                                    0.397092
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                       0.596311
# 1                                       0.423466
# 2                                       0.452395
# 3                                       0.355146
# 4                                       0.559710
# ...                                          ...
# 1254                                    0.432665
# 1255                                    0.317742
# 1256                                    0.363869
# 1257                                    0.440764
# 1258                                    0.381677
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                       0.632179
# 1                                       0.446001
# 2                                       0.584362
# 3                                       0.490685
# 4                                       0.627945
# ...                                          ...
# 1254                                    0.428898
# 1255                                    0.347561
# 1256                                    0.372689
# 1257                                    0.442042
# 1258                                    0.380470
#
#       F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                     0.209500
# 1                                     0.147274
# 2                                     0.226165
# 3                                     0.233617
# 4                                     0.291699
# ...                                        ...
# 1254                                  0.042556
# 1255                                  0.422764
# 1256                                  0.462329
# 1257                                  0.104093
# 1258                                  0.052991
#
#       F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# 0                                        0.178389
# 1                                        0.282919
# 2                                        0.321936
# 3                                        0.187911
# 4                                        0.210346
# ...                                           ...
# 1254                                     0.136981
# 1255                                     0.358086
# 1256                                     0.259245
# 1257                                     0.162826
# 1258                                     0.227318
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  \
# 0                                          0.032262
# 1                                          0.175538
# 2                                          0.164298
# 3                                          0.038932
# 4                                          0.112102
# ...                                             ...
# 1254                                       0.009610
# 1255                                       0.306875
# 1256                                       0.118235
# 1257                                       0.065396
# 1258                                       0.087805
#
#       F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope  \
# 0                                         0.261604
# 1                                         0.267522
# 2                                         0.311106
# 3                                         0.222829
# 4                                         0.258617
# ...                                            ...
# 1254                                      0.209519
# 1255                                      0.228330
# 1256                                      0.245574
# 1257                                      0.205408
# 1258                                      0.235091
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope  ...  \
# 0                                           0.070276  ...
# 1                                           0.068505  ...
# 2                                           0.203101  ...
# 3                                           0.040867  ...
# 4                                           0.044221  ...
# ...                                              ...  ...
# 1254                                        0.008897  ...
# 1255                                        0.014988  ...
# 1256                                        0.060586  ...
# 1257                                        0.005887  ...
# 1258                                        0.048350  ...
#
#       VoicedSegmentsPerSec  MeanVoicedSegmentLengthSec  \
# 0                 0.330578                    0.037114
# 1                 0.264558                    0.055237
# 2                 0.344937                    0.038350
# 3                 0.337101                    0.039662
# 4                 0.161629                    0.090247
# ...                    ...                         ...
# 1254              0.192274                    0.065019
# 1255              0.396111                    0.023316
# 1256              0.376332                    0.022740
# 1257              0.155720                    0.063989
# 1258              0.324766                    0.029237
#
#       StddevVoicedSegmentLengthSec  MeanUnvoicedSegmentLength  \
# 0                         0.117179                   0.047826
# 1                         0.089090                   0.057971
# 2                         0.090084                   0.050725
# 3                         0.074729                   0.045894
# 4                         0.320940                   0.045894
# ...                            ...                        ...
# 1254                      0.064878                   0.086957
# 1255                      0.090696                   0.077122
# 1256                      0.107705                   0.091938
# 1257                      0.077539                   0.134058
# 1258                      0.098803                   0.072464
#
#       StddevUnvoicedSegmentLength  equivalentSoundLevel_dBp  actor_id  \
# 0                        0.088380                  0.731259         1
# 1                        0.000000                  0.725443         1
# 2                        0.049834                  0.742759         1
# 3                        0.040150                  0.789177         1
# 4                        0.058668                  0.764986         1
# ...                           ...                       ...       ...
# 1254                     0.127309                  0.693686        10
# 1255                     0.096082                  0.760948        10
# 1256                     0.147996                  0.786001        10
# 1257                     0.268334                  0.721901        10
# 1258                     0.082329                  0.726299        10
#
#       file_id  target  group
# 0           0       1      4
# 1           1       1      4
# 2           2       1      4
# 3           3       1      4
# 4           4       1      4
# ...       ...     ...    ...
# 1254     1255      17      5
# 1255     1256      17      5
# 1256     1257      17      5
# 1257     1258      17      5
# 1258     1259      17      5
#
# [1259 rows x 92 columns]

# %%
train_gemaps_scaled_groups_df
# Out:
#       F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                              0.579782
# 1                              0.393945
# 2                              0.487920
# 3                              0.415525
# 4                              0.578382
# ...                                 ...
# 1254                           0.455030
# 1255                           0.220083
# 1256                           0.270762
# 1257                           0.450948
# 1258                           0.349244
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                   0.276111
# 1                                   0.343674
# 2                                   0.288303
# 3                                   0.320765
# 4                                   0.277224
# ...                                      ...
# 1254                                0.051548
# 1255                                0.513768
# 1256                                0.520014
# 1257                                0.089263
# 1258                                0.336031
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                       0.533631
# 1                                       0.384970
# 2                                       0.466380
# 3                                       0.357067
# 4                                       0.455800
# ...                                          ...
# 1254                                    0.459465
# 1255                                    0.031770
# 1256                                    0.024084
# 1257                                    0.419079
# 1258                                    0.397092
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                       0.596311
# 1                                       0.423466
# 2                                       0.452395
# 3                                       0.355146
# 4                                       0.559710
# ...                                          ...
# 1254                                    0.432665
# 1255                                    0.317742
# 1256                                    0.363869
# 1257                                    0.440764
# 1258                                    0.381677
#
#       F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                       0.632179
# 1                                       0.446001
# 2                                       0.584362
# 3                                       0.490685
# 4                                       0.627945
# ...                                          ...
# 1254                                    0.428898
# 1255                                    0.347561
# 1256                                    0.372689
# 1257                                    0.442042
# 1258                                    0.380470
#
#       F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                     0.209500
# 1                                     0.147274
# 2                                     0.226165
# 3                                     0.233617
# 4                                     0.291699
# ...                                        ...
# 1254                                  0.042556
# 1255                                  0.422764
# 1256                                  0.462329
# 1257                                  0.104093
# 1258                                  0.052991
#
#       F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# 0                                        0.178389
# 1                                        0.282919
# 2                                        0.321936
# 3                                        0.187911
# 4                                        0.210346
# ...                                           ...
# 1254                                     0.136981
# 1255                                     0.358086
# 1256                                     0.259245
# 1257                                     0.162826
# 1258                                     0.227318
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  \
# 0                                          0.032262
# 1                                          0.175538
# 2                                          0.164298
# 3                                          0.038932
# 4                                          0.112102
# ...                                             ...
# 1254                                       0.009610
# 1255                                       0.306875
# 1256                                       0.118235
# 1257                                       0.065396
# 1258                                       0.087805
#
#       F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope  \
# 0                                         0.261604
# 1                                         0.267522
# 2                                         0.311106
# 3                                         0.222829
# 4                                         0.258617
# ...                                            ...
# 1254                                      0.209519
# 1255                                      0.228330
# 1256                                      0.245574
# 1257                                      0.205408
# 1258                                      0.235091
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope  ...  \
# 0                                           0.070276  ...
# 1                                           0.068505  ...
# 2                                           0.203101  ...
# 3                                           0.040867  ...
# 4                                           0.044221  ...
# ...                                              ...  ...
# 1254                                        0.008897  ...
# 1255                                        0.014988  ...
# 1256                                        0.060586  ...
# 1257                                        0.005887  ...
# 1258                                        0.048350  ...
#
#       loudnessPeaksPerSec  VoicedSegmentsPerSec  MeanVoicedSegmentLengthSec  \
# 0                0.718996              0.330578                    0.037114
# 1                0.792587              0.264558                    0.055237
# 2                0.611349              0.344937                    0.038350
# 3                0.661599              0.337101                    0.039662
# 4                0.602913              0.161629                    0.090247
# ...                   ...                   ...                         ...
# 1254             0.456192              0.192274                    0.065019
# 1255             0.193118              0.396111                    0.023316
# 1256             0.183356              0.376332                    0.022740
# 1257             0.317359              0.155720                    0.063989
# 1258             0.369043              0.324766                    0.029237
#
#       StddevVoicedSegmentLengthSec  MeanUnvoicedSegmentLength  \
# 0                         0.117179                   0.047826
# 1                         0.089090                   0.057971
# 2                         0.090084                   0.050725
# 3                         0.074729                   0.045894
# 4                         0.320940                   0.045894
# ...                            ...                        ...
# 1254                      0.064878                   0.086957
# 1255                      0.090696                   0.077122
# 1256                      0.107705                   0.091938
# 1257                      0.077539                   0.134058
# 1258                      0.098803                   0.072464
#
#       StddevUnvoicedSegmentLength  actor_id  file_id  target  group
# 0                        0.088380         1        0       1      4
# 1                        0.000000         1        1       1      4
# 2                        0.049834         1        2       1      4
# 3                        0.040150         1        3       1      4
# 4                        0.058668         1        4       1      4
# ...                           ...       ...      ...     ...    ...
# 1254                     0.127309        10     1255      17      5
# 1255                     0.096082        10     1256      17      5
# 1256                     0.147996        10     1257      17      5
# 1257                     0.268334        10     1258      17      5
# 1258                     0.082329        10     1259      17      5
#
# [1259 rows x 66 columns]

# %% [markdown]
# #### Check if there are some null values

# %%
train_egemaps_scaled_groups_df['group'].isnull().any()
# Out:
# False

# %%
train_gemaps_scaled_groups_df['group'].isnull().any()
# Out:
# False
